# %% [markdown]
# Dataset Extraction

# %%
# !rm -r /content/dataset
# !unzip dataset.zip
# !rm -r __MACOSX
# Out:
# rm: cannot remove '/content/dataset': No such file or directory
# Archive:  dataset.zip
#    creating: dataset/
#   inflating: __MACOSX/._dataset
#    creating: dataset/sheila_others/
#   inflating: __MACOSX/dataset/._sheila_others
#   inflating: dataset/.DS_Store
#   inflating: __MACOSX/dataset/._.DS_Store
#    creating: dataset/sheila_0/
#   inflating: __MACOSX/dataset/._sheila_0
#   inflating: dataset/sheila_others/sheila.3efa7ec4_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3efa7ec4_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.9f869f70_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9f869f70_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.cee22275_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.cee22275_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.74fc51e5_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.74fc51e5_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.6c429c7b_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6c429c7b_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.24ed94ab_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.24ed94ab_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.8781f4c1_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.8781f4c1_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.6e8b9b7b_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6e8b9b7b_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.13dce503_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.13dce503_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.05739450_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.05739450_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.333d7ddb_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.333d7ddb_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.f34e6f44_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f34e6f44_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.4ca37738_nohash_3.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4ca37738_nohash_3.wav
#   inflating: dataset/sheila_others/sheila.173ce2be_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.173ce2be_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.0f2442b6_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0f2442b6_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.fc94edb0_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.fc94edb0_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.4a4e28f1_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4a4e28f1_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.146d97db_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.146d97db_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.ab00c4b2_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ab00c4b2_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.caf9fceb_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.caf9fceb_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.efab2cbd_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.efab2cbd_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a8f45bdc_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a8f45bdc_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.3ca784ec_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3ca784ec_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.274c008f_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.274c008f_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.baf01c1f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.baf01c1f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.105a0eea_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.105a0eea_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.34e8c726_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.34e8c726_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.c7dc7278_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.c7dc7278_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.22cb56b3_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.22cb56b3_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.0227998e_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0227998e_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a4b21cbc_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a4b21cbc_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0a196374_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.e0611c84_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e0611c84_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.d103dd6e_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d103dd6e_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.44dad20e_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.44dad20e_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.00f0204f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.00f0204f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a1e71565_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a1e71565_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.18ffa72d_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.18ffa72d_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.d33df435_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d33df435_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.9a356ab9_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9a356ab9_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.4fce7686_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4fce7686_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a1dd919f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a1dd919f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.e54a0f16_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e54a0f16_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.f9318c93_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f9318c93_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.40115b19_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.40115b19_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.377e916b_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.377e916b_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.62ef962d_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.62ef962d_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.d7467392_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d7467392_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.05cf43ef_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.05cf43ef_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.d069e6ff_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d069e6ff_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.ec74a8a5_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ec74a8a5_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.44b9b0c1_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.44b9b0c1_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.90b94017_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.90b94017_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.f864cd4a_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f864cd4a_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.42ccb57a_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.42ccb57a_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.e0322f2c_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e0322f2c_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.1ecfb537_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1ecfb537_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.6301e683_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6301e683_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.14775481_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.14775481_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.c137814b_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.c137814b_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.d3d8fcd0_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d3d8fcd0_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b089169d_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b089169d_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.aa753bb9_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.aa753bb9_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.24befdb3_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.24befdb3_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.85834399_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.85834399_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.e1aa22e4_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e1aa22e4_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.422f8cf1_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.422f8cf1_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7117fb6d_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7117fb6d_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.39dce8cc_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.39dce8cc_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.422f8cf1_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.422f8cf1_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.e1aa22e4_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e1aa22e4_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.7117fb6d_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7117fb6d_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.86f3558f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.86f3558f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b93528e3_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b93528e3_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.85834399_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.85834399_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.80fe1dc7_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.80fe1dc7_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.c137814b_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.c137814b_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.d5c41d6a_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d5c41d6a_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.fbb2f6cc_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.fbb2f6cc_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.e0322f2c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e0322f2c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a293e285_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a293e285_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.823353e5_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.823353e5_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.f864cd4a_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f864cd4a_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.ec74a8a5_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ec74a8a5_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.bab36420_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.bab36420_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.fffcabd1_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.fffcabd1_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.4a803e67_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4a803e67_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a1533da4_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a1533da4_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.40115b19_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.40115b19_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a1dd919f_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a1dd919f_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.97addd88_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.97addd88_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.30aabd44_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.30aabd44_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.d33df435_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d33df435_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.30f6e665_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.30f6e665_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.00f0204f_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.00f0204f_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.44dad20e_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.44dad20e_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.4bc2c2c5_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4bc2c2c5_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.3b852f6f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3b852f6f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.0227998e_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0227998e_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.22cb56b3_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.22cb56b3_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.274c008f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.274c008f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.34e8c726_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.34e8c726_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.105a0eea_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.105a0eea_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.3437d72e_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3437d72e_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.3ca784ec_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3ca784ec_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a8f45bdc_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a8f45bdc_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.efab2cbd_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.efab2cbd_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.7e1054e7_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7e1054e7_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.caf9fceb_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.caf9fceb_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.ab00c4b2_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ab00c4b2_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.146d97db_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.146d97db_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b6026214_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b6026214_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a77fbcfd_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a77fbcfd_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.fc94edb0_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.fc94edb0_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.4ca37738_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4ca37738_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.1e02ffc5_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1e02ffc5_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.0f2442b6_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0f2442b6_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.f9273a21_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f9273a21_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.05739450_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.05739450_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.b8897f1c_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b8897f1c_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.f34e6f44_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f34e6f44_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.24ed94ab_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.24ed94ab_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.beb49c22_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.beb49c22_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.6e8b9b7b_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6e8b9b7b_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.4f5c0b28_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4f5c0b28_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.499be02e_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.499be02e_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.3efa7ec4_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3efa7ec4_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.23da904f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.23da904f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7f581e94_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7f581e94_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.da76aa58_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.da76aa58_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.48a8a69d_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.48a8a69d_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.014f9f65_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.014f9f65_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.4e61bf96_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4e61bf96_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.de650823_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.de650823_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.66cbe2b3_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.66cbe2b3_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b575b5fb_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b575b5fb_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.4ca37738_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4ca37738_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.876c84d6_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.876c84d6_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7e2d5caf_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7e2d5caf_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.3a70ab7f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3a70ab7f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b8897f1c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b8897f1c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.4c6167ca_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4c6167ca_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.f839238a_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f839238a_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.893b3c11_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.893b3c11_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.8fce59ff_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.8fce59ff_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.95299b6c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.95299b6c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.caf9fceb_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.caf9fceb_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.256c0a05_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.256c0a05_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b7a6f709_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b7a6f709_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.bcdaa7a9_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.bcdaa7a9_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7c86c03e_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7c86c03e_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b6ebe225_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b6ebe225_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.1cb788bc_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1cb788bc_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.365531e2_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.365531e2_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.85c5eaa0_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.85c5eaa0_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.03401e93_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.03401e93_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.15c563d7_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.15c563d7_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.60472d26_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.60472d26_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.21307344_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.21307344_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.258f4559_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.258f4559_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.9a356ab9_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9a356ab9_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.5f01c798_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.5f01c798_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.ab76ac76_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ab76ac76_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.0c09f202_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0c09f202_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.0d53e045_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0d53e045_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.57cb3575_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.57cb3575_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.856eb138_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.856eb138_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.40115b19_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.40115b19_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.a1533da4_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a1533da4_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7e556a2c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7e556a2c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.6982fc2a_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6982fc2a_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a1c63f25_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a1c63f25_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.118261a9_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.118261a9_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.62ef962d_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.62ef962d_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.674ca5ea_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.674ca5ea_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.05cf43ef_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.05cf43ef_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.fffcabd1_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.fffcabd1_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.135c6841_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.135c6841_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.bdd22e4d_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.bdd22e4d_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a996cf66_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a996cf66_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.9b6c08ba_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9b6c08ba_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.1993db46_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1993db46_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.73cccfaf_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.73cccfaf_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.6adb8ad9_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6adb8ad9_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.39dce8cc_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.39dce8cc_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a9ca1818_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a9ca1818_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.026290a7_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.026290a7_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.026290a7_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.026290a7_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.39dce8cc_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.39dce8cc_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.a591c2ea_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a591c2ea_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a827e3a1_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a827e3a1_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.73cccfaf_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.73cccfaf_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.9b6c08ba_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9b6c08ba_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a996cf66_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a996cf66_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.62641b88_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.62641b88_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.135c6841_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.135c6841_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.4ec7d027_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4ec7d027_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.5f1253e9_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.5f1253e9_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.c2d15ea5_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.c2d15ea5_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.fffcabd1_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.fffcabd1_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.890cc926_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.890cc926_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.ea7ca285_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ea7ca285_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.283d7a53_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.283d7a53_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.05cf43ef_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.05cf43ef_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.118261a9_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.118261a9_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.3c257192_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3c257192_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.8d9cc260_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.8d9cc260_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.62ef962d_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.62ef962d_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.d71ad617_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d71ad617_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b6573c88_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b6573c88_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.6982fc2a_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6982fc2a_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.fb01a182_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.fb01a182_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.88e90bc1_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.88e90bc1_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a1533da4_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a1533da4_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.954f190f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.954f190f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.0d53e045_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0d53e045_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.2f0a410b_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.2f0a410b_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.00f0204f_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.00f0204f_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.fe5c4a7a_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.fe5c4a7a_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.9a356ab9_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9a356ab9_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.5f01c798_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.5f01c798_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a04817c2_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a04817c2_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.258f4559_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.258f4559_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.21307344_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.21307344_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.03401e93_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.03401e93_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.85c5eaa0_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.85c5eaa0_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.5efb758c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.5efb758c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.29fb33da_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.29fb33da_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.1cb788bc_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1cb788bc_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.0227998e_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0227998e_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.b6ebe225_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b6ebe225_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.6a861f21_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6a861f21_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7dc50b88_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7dc50b88_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7c86c03e_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7c86c03e_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.a9f38bae_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a9f38bae_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7e2d5caf_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7e2d5caf_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.f839238a_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f839238a_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.4c6167ca_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4c6167ca_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.3a69f765_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3a69f765_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b8897f1c_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b8897f1c_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.bbc30633_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.bbc30633_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.4ca37738_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4ca37738_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.b575b5fb_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b575b5fb_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.4e61bf96_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4e61bf96_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.48a8a69d_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.48a8a69d_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a928cc5b_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a928cc5b_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.35d1b6ee_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.35d1b6ee_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.37fc5d97_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.37fc5d97_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.38d78313_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.38d78313_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.4d4e17f5_nohash_3.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4d4e17f5_nohash_3.wav
#   inflating: dataset/sheila_others/sheila.c661be6e_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.c661be6e_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.71e6ab20_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.71e6ab20_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.079dfce3_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.079dfce3_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.4845bb10_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.4845bb10_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.19e98e89_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.19e98e89_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.66cff190_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.66cff190_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.d7ca14ef_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d7ca14ef_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.246d2c7f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.246d2c7f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.9f92fb7c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9f92fb7c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.11379f4d_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.11379f4d_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.ef2a3cfb_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ef2a3cfb_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.196e84b7_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.196e84b7_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.33903159_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.33903159_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a527cb3c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a527cb3c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.0397ecda_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0397ecda_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.f174517e_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f174517e_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.d1214f15_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d1214f15_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.3367cff6_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3367cff6_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.1d919a90_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1d919a90_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.e5d2e09d_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e5d2e09d_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.32561e9e_nohash_2.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.32561e9e_nohash_2.wav
#   inflating: dataset/sheila_others/sheila.982babaf_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.982babaf_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.6c0f6493_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6c0f6493_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.d21fd169_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d21fd169_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.1c50d874_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1c50d874_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.c33682f0_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.c33682f0_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a045368c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a045368c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.88f8a99c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.88f8a99c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b72e58c9_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b72e58c9_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.2b3f509b_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.2b3f509b_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a5d485dc_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a5d485dc_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.833a0279_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.833a0279_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.9785931e_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9785931e_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.1995cf9e_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1995cf9e_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.8601f33b_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.8601f33b_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.3852fca2_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.3852fca2_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.c885a039_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.c885a039_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.e2008f39_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e2008f39_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.11860c84_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.11860c84_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.6f5b4d3d_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6f5b4d3d_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.6414258b_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6414258b_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b17f5ba0_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b17f5ba0_nohash_0.wav
#   inflating: dataset/sheila_others/.DS_Store
#   inflating: __MACOSX/dataset/sheila_others/._.DS_Store
#   inflating: dataset/sheila_others/sheila.ec7d1151_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ec7d1151_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.e0ff1e9c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e0ff1e9c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.db43cd03_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.db43cd03_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.1fe4c891_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1fe4c891_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.e882abb2_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e882abb2_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.ae927455_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ae927455_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.435695e3_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.435695e3_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.0aad3227_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.0aad3227_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7f74626f_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7f74626f_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.437455be_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.437455be_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.bbf38549_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.bbf38549_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a95dbfd4_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a95dbfd4_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.d5dd88da_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d5dd88da_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.1093c8e7_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1093c8e7_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.a16b3102_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a16b3102_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.eaa83485_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.eaa83485_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.1093c8e7_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1093c8e7_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.7f208e83_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.7f208e83_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.d5dd88da_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d5dd88da_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.a95dbfd4_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a95dbfd4_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.9c06a3f3_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9c06a3f3_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.9a2e5b3c_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9a2e5b3c_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.750e3e75_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.750e3e75_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.d9ae8983_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.d9ae8983_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.ae927455_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ae927455_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.1fe4c891_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.1fe4c891_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.cc71bada_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.cc71bada_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.161fcca8_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.161fcca8_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.f0659908_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.f0659908_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b17f5ba0_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b17f5ba0_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.ed3c2d05_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ed3c2d05_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.ec7d1151_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.ec7d1151_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.6414258b_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6414258b_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.6f5b4d3d_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.6f5b4d3d_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.11860c84_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.11860c84_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.a4effc43_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.a4effc43_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.9f7079fe_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.9f7079fe_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.b29f8b23_nohash_0.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.b29f8b23_nohash_0.wav
#   inflating: dataset/sheila_others/sheila.e2008f39_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.e2008f39_nohash_1.wav
#   inflating: dataset/sheila_others/sheila.8601f33b_nohash_1.wav
#   inflating: __MACOSX/dataset/sheila_others/._sheila.8601f33b_nohash_1.wav
# ...
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s47.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s3.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s3.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s26.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s26.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s32.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s32.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s39.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s39.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s11.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s11.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s61.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s61.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s3.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s3.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s49.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s49.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s48.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s48.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s2.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s2.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s60.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s60.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s10.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s10.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s38.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s38.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s33.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s33.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s27.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s27.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s2.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s2.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s46.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s46.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s52.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s52.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s17.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s17.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s29.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s29.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s15.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s15.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s44.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s44.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s50.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s50.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s31.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s31.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s25.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s25.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s19.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s19.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s12.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s12.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s62.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s62.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s63.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s63.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s1.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s1.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s13.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s13.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s18.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s18.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s24.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s24.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s30.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s30.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s1.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s1.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s51.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s51.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s45.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s45.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s14.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s14.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s28.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s28.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s10.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s10.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s38.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s38.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s41.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s41.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s55.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s55.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s5.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s5.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s34.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s34.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s20.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s20.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s17.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s17.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s5.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s5.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s73.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s73.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s8.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s8.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s67.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s67.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s66.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s66.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s9.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s9.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s72.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s72.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s4.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s4.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s16.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s16.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s21.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s21.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s35.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s35.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s4.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s4.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s54.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s54.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s40.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s40.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s11.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s11.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s13.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s13.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s56.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s56.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s42.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s42.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s6.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s6.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s23.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s23.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s37.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s37.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s14.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s14.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s28.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s28.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s8.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s8.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s58.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s58.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s64.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s64.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s70.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s70.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s6.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s6.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s7.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s7.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s71.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s71.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s65.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s65.wav
#   inflating: dataset/sheila_0/sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s59.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5no9jpqn.ingestion-7dcc488448-zz5mz.s59.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s9.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s9.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s29.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s29.wav
#   inflating: dataset/sheila_0/sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s15.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaimoo.ingestion-7dcc488448-zz5mz.s15.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s36.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s36.wav
#   inflating: dataset/sheila_0/sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s22.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noab3b5.ingestion-7dcc488448-zz5mz.s22.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s7.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s7.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s43.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s43.wav
#   inflating: dataset/sheila_0/sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s57.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noar0lq.ingestion-7dcc488448-mjqvh.s57.wav
#   inflating: dataset/sheila_0/sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s12.wav
#   inflating: __MACOSX/dataset/sheila_0/._sheila_0.5noaksb4.ingestion-7dcc488448-mjqvh.s12.wav

# %% [markdown]
# Dividing the files in the desired folders, that will then be processed in .npy files

# %% [markdown]
# Division and organization:

# %%
import os
import shutil
import random
from tqdm import tqdm

def organize_wav_files(target_source_dir, other_source_dir, output_dir, target_user_id=0):

    os.makedirs(output_dir, exist_ok=True)
    subfolders = {
        "validation": (60, 120),
        "testing": (60, 120),
        "train_1": (1, 0),
        "train_8": (8, 0),
        "train_16": (16, 0),
        "train_64": (64, 0),
        "remain": (-1, -1)
    }

    for folder in subfolders:
        os.makedirs(os.path.join(output_dir, folder), exist_ok=True)

    target_files = [f for f in os.listdir(target_source_dir)
                   if f.endswith('.wav') and os.path.isfile(os.path.join(target_source_dir, f))]
    random.shuffle(target_files)

    other_files = []
    for root, _, files in os.walk(other_source_dir):
        for file in files:
            if file.endswith('.wav'):
                other_files.append(os.path.join(root, file))
    random.shuffle(other_files)

    required_target = sum(v[0] for k, v in subfolders.items() if k != "remain")
    required_other = sum(v[1] for k, v in subfolders.items() if k != "remain")

    if len(target_files) < required_target:
        raise ValueError(f"Need {required_target} target files, found {len(target_files)}")
    if len(other_files) < required_other:
        raise ValueError(f"Need {required_other} non-target files, found {len(other_files)}")

    target_idx = 0
    other_idx = 0

    for folder, (target_count, other_count) in subfolders.items():
        if folder == "remain":
            continue

        for i in range(target_count):
            src = os.path.join(target_source_dir, target_files[target_idx])
            dst = os.path.join(output_dir, folder, f"target_{target_files[target_idx]}")
            shutil.copy(src, dst)
            target_idx += 1

        for i in range(other_count):
            src = other_files[other_idx]
            dst = os.path.join(output_dir, folder, f"other_{os.path.basename(src)}")
            shutil.copy(src, dst)
            other_idx += 1

    for remaining_target in target_files[target_idx:]:
        src = os.path.join(target_source_dir, remaining_target)
        dst = os.path.join(output_dir, "remain", f"target_{remaining_target}")
        shutil.copy(src, dst)

    for remaining_other in other_files[other_idx:]:
        dst = os.path.join(output_dir, "remain", f"other_{os.path.basename(remaining_other)}")
        shutil.copy(remaining_other, dst)

    used_target = target_idx
    used_other = other_idx
    remaining_target = len(target_files) - target_idx
    remaining_other = len(other_files) - other_idx

    print("\nOrganization complete.")
    print(f"Used {used_target} target files and {used_other} non-target files")
    print(f"Remaining target files moved to 'remain': {remaining_target}")
    print(f"Remaining non-target files moved to 'remain': {remaining_other}")
    print("\nFinal counts per folder:")
    for folder in subfolders:
        if folder == "remain":
            target_count = len([f for f in os.listdir(os.path.join(output_dir, folder))
                             if f.startswith('target_')])
            other_count = len([f for f in os.listdir(os.path.join(output_dir, folder))
                            if f.startswith('other_')])
            print(f"{folder}: {target_count} target, {other_count} non-target (remaining)")
        else:
            expected_target, expected_other = subfolders[folder]
            actual_target = len([f for f in os.listdir(os.path.join(output_dir, folder))
                              if f.startswith('target_')])
            actual_other = len([f for f in os.listdir(os.path.join(output_dir, folder))
                             if f.startswith('other_')])
            print(f"{folder}: {actual_target}/{expected_target} target, {actual_other}/{expected_other} non-target")

if __name__ == "__main__":
    target_speaker_dir = "/content/dataset/sheila_0/"
    other_speakers_dir = "/content/dataset/sheila_others/"
    output_directory = "/content/dataset/sheila_0_organized/"

    organize_wav_files(
        target_source_dir=target_speaker_dir,
        other_source_dir=other_speakers_dir,
        output_dir=output_directory,
        target_user_id=0
    )

    # !rm -r /content/dataset/sheila_0
    # !rm -r /content/dataset/sheila_others
# Out:
# Organization complete.
# Used 209 target files and 240 non-target files
# Remaining target files moved to 'remain': 47
# Remaining non-target files moved to 'remain': 1782
#
# Final counts per folder:
# validation: 60/60 target, 120/120 non-target
# testing: 60/60 target, 120/120 non-target
# train_1: 1/1 target, 0/0 non-target
# train_8: 8/8 target, 0/0 non-target
# train_16: 16/16 target, 0/0 non-target
# train_64: 64/64 target, 0/0 non-target
# remain: 47 target, 1782 non-target (remaining)

# %% [markdown]
# MFE block conversion and .npz file generation

# %%
import os
import shutil
import numpy as np
import librosa
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy.fftpack import dct
from scipy.signal import get_window
import soundfile as sf
from collections import defaultdict

SAMPLE_RATE = 16000
FRAME_DUR = 0.032
FRAME_SIZE = int(SAMPLE_RATE * FRAME_DUR)
FRAME_STRIDE_DUR = 0.024
FRAME_STRIDE = int(SAMPLE_RATE * FRAME_STRIDE_DUR)
NUM_BINS = FRAME_SIZE // 2
FILTER_NUMBER = 40
MIN_FREQ = 0
MAX_FREQ = SAMPLE_RATE // 2
COEFFICIENT = 0.96875
NOISE_FLOOR = -40.0

def remove_all_folders_except(parent_dir, folder_to_keep):
    keep_path = os.path.join(parent_dir, folder_to_keep)
    if not os.path.exists(keep_path):
        print(f"Warning: '{folder_to_keep}' doesn't exist in {parent_dir}")
        return

    for item in os.listdir(parent_dir):
        item_path = os.path.join(parent_dir, item)
        if os.path.isdir(item_path) and item != folder_to_keep:
            print(f"Removing: {item_path}")
            try:
                shutil.rmtree(item_path)
            except Exception as e:
                print(f"Failed to remove {item_path}: {e}")

def pre_emphasis(audio):
    emphasized = np.zeros_like(audio, dtype=np.float32)
    emphasized[0] = audio[0] / 32768.0
    for i in range(1, len(audio)):
        emphasized[i] = (audio[i] / 32768.0) - COEFFICIENT * (audio[i-1] / 32768.0)
    return emphasized

def apply_windowing(frame):
    window = 0.54 - 0.46 * np.cos(2 * np.pi * np.arange(len(frame)) / (len(frame) - 1))
    return frame * window

def hz_to_mel(hz):
    return 1127.0 * np.log10(1 + hz / 700.0)

def mel_to_hz(mel):
    return 700 * (10 ** (mel / 1127.0) - 1)

def create_mel_filterbank():
    min_mel = hz_to_mel(MIN_FREQ)
    max_mel = hz_to_mel(MAX_FREQ)
    #mel_points = np.linspace(min_mel, max_mel, FILTER_NUMBER + 2)
    #hz_points = mel_to_hz(mel_points)
    mel_points = np.zeros(FILTER_NUMBER + 2)
    mel_spacing = (max_mel - min_mel) / (FILTER_NUMBER + 1)
    for i in range(FILTER_NUMBER + 2):
        mel_points[i] = mel_to_hz(min_mel + i * mel_spacing)
        if mel_points[i] > MAX_FREQ:
            mel_points[i] = MAX_FREQ

    #bin_indices = np.floor((NUM_BINS) * hz_points / (SAMPLE_RATE / 2)).astype(int)
    #bin_indices = np.clip(bin_indices, 0, NUM_BINS - 1)
    bin_indices = np.zeros(FILTER_NUMBER + 2, dtype=int)
    for i in range(FILTER_NUMBER + 2):
        bin_indices[i] = int(mel_points[i] * (NUM_BINS - 1) / (SAMPLE_RATE / 2.0))
        bin_indices[i] = max(0, min(NUM_BINS - 1, bin_indices[i]))

    filterbank = np.zeros((FILTER_NUMBER, NUM_BINS))

    for i in range(FILTER_NUMBER):
        left = bin_indices[i]
        middle = bin_indices[i+1]
        right = bin_indices[i+2]

        if left == middle:
            middle = min(left + 1, NUM_BINS - 1)
        if middle == right:
            right = min(middle + 1, NUM_BINS - 1)

        #filterbank[i, left:middle] = np.linspace(0, 1, middle - left)
        for j in range(left, middle):
            filterbank[i, j] = (j - left) / (middle - left)

        #filterbank[i, middle:right] = np.linspace(1, 0, right - middle)
        for j in range(middle, right):
            filterbank[i, j] = 1.0 - (j - middle) / (right - middle)
    return filterbank

def compute_spectrogram(audio, show_plot=False):
    num_samples = len(audio)
    total_duration = num_samples / SAMPLE_RATE
    num_frames_full_second = int((total_duration - FRAME_DUR) / FRAME_STRIDE_DUR) + 1
    num_frames = min(num_frames_full_second, 40)
    pre_emphasis_array = pre_emphasis(audio)
    spectrogram = np.zeros((num_frames, NUM_BINS))

    for frame in range(num_frames):
        start = frame * FRAME_STRIDE
        end = start + FRAME_SIZE
        segment = pre_emphasis_array[start:end]
        if len(segment) < FRAME_SIZE:
            segment = np.pad(segment, (0, FRAME_SIZE - len(segment)))

        windowed = apply_windowing(segment)
        fft = np.fft.rfft(windowed, n=FRAME_SIZE)
        magnitude = np.abs(fft)
        spectrogram[frame] = magnitude[:NUM_BINS]

    mel_filterbank = create_mel_filterbank()
    mel_spectrogram = np.dot(spectrogram, mel_filterbank.T)
    log_mel_spectrogram = 10* np.log10(mel_spectrogram + 1e-20)

    log_mel_spectrogram = (log_mel_spectrogram - NOISE_FLOOR) / (-NOISE_FLOOR + 12)
    log_mel_spectrogram = np.clip(log_mel_spectrogram, 0, 1)
    quantized = np.round(log_mel_spectrogram * 256) / 256.0
    quantized = np.where(quantized >= 0.65, quantized, 0)
    quantized = quantized[:40]

    if show_plot:
        plt.figure(figsize=(10, 6))
        time_axis = np.linspace(0, 0.968, 40)
        plt.imshow(quantized.T, aspect='auto', origin='lower',
                  extent=[0, 0.968, 0, FILTER_NUMBER])
        plt.colorbar(label='Magnitude')
        plt.xlabel('Time (s)')
        plt.ylabel('Mel filter index')
        plt.title('40x40 Mel Spectrogram (0.968s duration)')
        plt.show()

    return quantized

import os
import shutil
import numpy as np
import librosa
from tqdm import tqdm
import matplotlib.pyplot as plt
import soundfile as sf
from collections import defaultdict

def process_folder_to_npz(folder_path, output_npz_path, target_user_id, remain_folder=None, is_training=False):
    """Process all WAV files in a folder, using remain folder as fallback"""
    features = []
    labels = []
    filenames = []
    remain_files_used = 0

    wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    remain_files = []
    if remain_folder and os.path.exists(remain_folder):
        if is_training:
            remain_files = [f for f in os.listdir(remain_folder)
                          if f.endswith('.wav') and f.startswith('target_')
                          and os.path.isfile(os.path.join(remain_folder, f))]
        else:
            remain_files = [f for f in os.listdir(remain_folder)
                          if f.endswith('.wav') and os.path.isfile(os.path.join(remain_folder, f))]

        random.shuffle(remain_files)

    for wav_file in tqdm(wav_files, desc=f"Processing {os.path.basename(folder_path)}"):
        audio_path = os.path.join(folder_path, wav_file)
        success = False

        try:
            audio, sr = librosa.load(audio_path, sr=SAMPLE_RATE, mono=True)
            audio_int16 = (audio * 32767).astype(np.int16)

            if len(audio_int16) == SAMPLE_RATE:
                mfe = compute_spectrogram(audio_int16)
                mfe = mfe[..., np.newaxis]
                features.append(mfe)

                label = target_user_id if wav_file.startswith('target_') else -1
                labels.append(label)
                filenames.append(wav_file)
                success = True
            else:
                print(f"Duration mismatch: {wav_file} has {len(audio_int16)/SAMPLE_RATE:.2f}s (expected 1.0)")
        except Exception as e:
            print(f"Error processing {wav_file}: {str(e)}")

        if not success and remain_files:
            remain_file = remain_files.pop()
            remain_path = os.path.join(remain_folder, remain_file)

            try:
                audio, sr = librosa.load(remain_path, sr=SAMPLE_RATE, mono=True)
                audio_int16 = (audio * 32767).astype(np.int16)

                if len(audio_int16) == SAMPLE_RATE:
                    mfe = compute_spectrogram(audio_int16)
                    mfe = mfe[..., np.newaxis]
                    features.append(mfe)

                    if is_training:
                        label = target_user_id
                    else:
                        label = target_user_id if remain_file.startswith('target_') else -1

                    labels.append(label)
                    filenames.append(f"remain_replacement_{remain_file}")
                    remain_files_used += 1
                    success = True
                else:
                    print(f"Remain file duration mismatch: {remain_file}")
            except Exception as e:
                print(f"Error processing remain file {remain_file}: {str(e)}")

        if not success:
            print(f"Could not process {wav_file} and no valid remain files available")

    features_array = np.array(features, dtype=np.float32)
    labels_array = np.array(labels, dtype=np.int32)

    np.savez_compressed(
        output_npz_path,
        features=features_array,
        filenames=np.array(filenames),
        labels=labels_array
    )

    print(f"\nSaved {len(features)} segments to {output_npz_path}")
    print(f"Class distribution: Target={np.sum(labels_array == target_user_id)}, Non-target={np.sum(labels_array != target_user_id)}")
    if remain_files_used > 0:
        print(f"Used {remain_files_used} files from remain folder as replacements")

def process_all_folders(base_dir, target_user_id=0):
    """Process all subfolders in the organized directory"""
    subfolders = [
        "train_1",
        "train_8",
        "train_16",
        "train_64",
        "validation",
        "testing"
    ]

    output_dir = os.path.join(base_dir, "npz_features")
    os.makedirs(output_dir, exist_ok=True)

    # Path to remain folder
    remain_folder = os.path.join(base_dir, "remain")

    for folder in subfolders:
        folder_path = os.path.join(base_dir, folder)
        if os.path.exists(folder_path):
            if "train" in folder:
                output_filename = f"{folder}_{target_user_id}_features.npz"
                is_training = True
            else:
                output_filename = f"{folder}_features.npz"
                is_training = False

            output_path = os.path.join(output_dir, output_filename)

            # Process folder with remain folder as fallback
            process_folder_to_npz(
                folder_path,
                output_path,
                target_user_id,
                remain_folder=remain_folder,
                is_training=is_training
            )

if __name__ == "__main__":
    organized_dir = "/content/dataset/sheila_0_organized"
    target_speaker_id = 0

    print("Verifying folder structure...")
    for folder in ["validation", "testing", "train_1", "train_8", "train_16", "train_64", "remain"]:
        path = os.path.join(organized_dir, folder)
        if os.path.exists(path):
            files = [f for f in os.listdir(path) if f.endswith('.wav')]
            print(f"{folder}: {len(files)} files")

    process_all_folders(organized_dir, target_user_id=target_speaker_id)
    remove_all_folders_except(parent_dir=organized_dir, folder_to_keep="npz_features")
# Out:
# Verifying folder structure...
# validation: 180 files
# testing: 180 files
# train_1: 1 files
# train_8: 8 files
# train_16: 16 files
# train_64: 64 files
# remain: 1829 files
# Processing train_1: 100%|██████████| 1/1 [00:17<00:00, 17.91s/it]
# Saved 1 segments to /content/dataset/sheila_0_organized/npz_features/train_1_0_features.npz
# Class distribution: Target=1, Non-target=0
# Processing train_8: 100%|██████████| 8/8 [00:00<00:00, 13.83it/s]
# Saved 8 segments to /content/dataset/sheila_0_organized/npz_features/train_8_0_features.npz
# Class distribution: Target=8, Non-target=0
# Processing train_16: 100%|██████████| 16/16 [00:01<00:00, 13.86it/s]
# Saved 16 segments to /content/dataset/sheila_0_organized/npz_features/train_16_0_features.npz
# Class distribution: Target=16, Non-target=0
# Processing train_64: 100%|██████████| 64/64 [00:05<00:00, 10.75it/s]
# Saved 64 segments to /content/dataset/sheila_0_organized/npz_features/train_64_0_features.npz
# Class distribution: Target=64, Non-target=0
# Processing validation:   7%|▋         | 12/180 [00:00<00:11, 14.02it/s]
# Duration mismatch: other_sheila.72be9202_nohash_2.wav has 0.98s (expected 1.0)
# Processing validation:  14%|█▍        | 26/180 [00:01<00:11, 13.90it/s]
# Duration mismatch: other_sheila.462dca36_nohash_1.wav has 0.60s (expected 1.0)
# Processing validation:  17%|█▋        | 30/180 [00:02<00:10, 14.05it/s]
# Duration mismatch: other_sheila.82d0d3ba_nohash_0.wav has 0.98s (expected 1.0)
# Processing validation:  37%|███▋      | 66/180 [00:04<00:08, 14.13it/s]
# Duration mismatch: other_sheila.827421c4_nohash_0.wav has 0.77s (expected 1.0)
# Processing validation:  40%|████      | 72/180 [00:05<00:07, 13.95it/s]
# Duration mismatch: other_sheila.f6a380e7_nohash_0.wav has 0.51s (expected 1.0)
# Processing validation:  48%|████▊     | 86/180 [00:06<00:06, 13.56it/s]
# Duration mismatch: other_sheila.18ffa72d_nohash_0.wav has 0.84s (expected 1.0)
# Processing validation:  50%|█████     | 90/180 [00:06<00:06, 14.08it/s]
# Duration mismatch: other_sheila.b10b0654_nohash_0.wav has 0.85s (expected 1.0)
# Processing validation:  53%|█████▎    | 95/180 [00:06<00:05, 16.26it/s]
# Duration mismatch: other_sheila.a73be046_nohash_0.wav has 0.73s (expected 1.0)
# Remain file duration mismatch: other_sheila.1cc80e39_nohash_0.wav
# Could not process other_sheila.a73be046_nohash_0.wav and no valid remain files available
# Processing validation:  65%|██████▌   | 117/180 [00:08<00:04, 13.85it/s]
# Duration mismatch: other_sheila.78030270_nohash_1.wav has 0.98s (expected 1.0)
# Processing validation:  68%|██████▊   | 123/180 [00:08<00:04, 13.96it/s]
# Duration mismatch: other_sheila.fbe51750_nohash_3.wav has 0.94s (expected 1.0)
# Processing validation:  77%|███████▋  | 139/180 [00:10<00:05,  7.44it/s]
# Duration mismatch: other_sheila.12529547_nohash_0.wav has 0.93s (expected 1.0)
# Processing validation:  97%|█████████▋| 175/180 [00:13<00:00, 16.23it/s]
# Duration mismatch: other_sheila.c578beb0_nohash_1.wav has 0.94s (expected 1.0)
# Remain file duration mismatch: other_sheila.38c30a4a_nohash_0.wav
# Could not process other_sheila.c578beb0_nohash_1.wav and no valid remain files available
# Processing validation:  98%|█████████▊| 177/180 [00:13<00:00, 15.50it/s]
# Duration mismatch: other_sheila.cc3d1613_nohash_1.wav has 0.94s (expected 1.0)
# Processing validation: 100%|██████████| 180/180 [00:14<00:00, 12.78it/s]
# Saved 178 segments to /content/dataset/sheila_0_organized/npz_features/validation_features.npz
# Class distribution: Target=60, Non-target=118
# Used 11 files from remain folder as replacements
# Processing testing:   6%|▌         | 10/180 [00:00<00:11, 14.51it/s]
# Duration mismatch: other_sheila.31601aad_nohash_0.wav has 0.81s (expected 1.0)
# Processing testing:   7%|▋         | 12/180 [00:00<00:11, 14.23it/s]
# Duration mismatch: other_sheila.708a9569_nohash_3.wav has 0.94s (expected 1.0)
# Processing testing:  16%|█▌        | 28/180 [00:01<00:10, 14.27it/s]
# Duration mismatch: other_sheila.39dce8cc_nohash_2.wav has 0.79s (expected 1.0)
# Processing testing:  20%|██        | 36/180 [00:02<00:10, 14.29it/s]
# Duration mismatch: other_sheila.8d4cdc60_nohash_2.wav has 0.98s (expected 1.0)
# Processing testing:  24%|██▍       | 44/180 [00:03<00:09, 13.97it/s]
# Duration mismatch: other_sheila.7014b07e_nohash_0.wav has 0.88s (expected 1.0)
# Processing testing:  31%|███       | 55/180 [00:03<00:07, 16.10it/s]
# Duration mismatch: other_sheila.cc3d1613_nohash_0.wav has 0.90s (expected 1.0)
# Remain file duration mismatch: other_sheila.37e8db82_nohash_0.wav
# Could not process other_sheila.cc3d1613_nohash_0.wav and no valid remain files available
# Duration mismatch: other_sheila.3659fc1c_nohash_0.wav has 0.46s (expected 1.0)
# Processing testing:  37%|███▋      | 67/180 [00:04<00:07, 14.25it/s]
# Duration mismatch: other_sheila.55feffd5_nohash_1.wav has 0.65s (expected 1.0)
# Processing testing:  44%|████▍     | 79/180 [00:05<00:07, 13.82it/s]
# Duration mismatch: other_sheila.31ac8b88_nohash_0.wav has 0.77s (expected 1.0)
# Processing testing:  48%|████▊     | 86/180 [00:06<00:05, 15.67it/s]
# Duration mismatch: other_sheila.ae927455_nohash_0.wav has 0.85s (expected 1.0)
# Remain file duration mismatch: other_sheila.0a5636ca_nohash_1.wav
# Could not process other_sheila.ae927455_nohash_0.wav and no valid remain files available
# Duration mismatch: other_sheila.9f92fb7c_nohash_1.wav has 0.98s (expected 1.0)
# Processing testing:  50%|█████     | 90/180 [00:06<00:06, 14.34it/s]
# Duration mismatch: other_sheila.13dce503_nohash_0.wav has 0.93s (expected 1.0)
# Processing testing:  53%|█████▎    | 96/180 [00:06<00:05, 14.10it/s]
# Duration mismatch: other_sheila.2296b1af_nohash_0.wav has 0.79s (expected 1.0)
# Processing testing:  58%|█████▊    | 104/180 [00:07<00:05, 13.54it/s]
# Duration mismatch: other_sheila.52bfbce8_nohash_0.wav has 0.77s (expected 1.0)
# Processing testing:  88%|████████▊ | 159/180 [00:12<00:01, 13.55it/s]
# Duration mismatch: other_sheila.8c0e5970_nohash_0.wav has 0.94s (expected 1.0)
# Duration mismatch: other_sheila.56cd307a_nohash_1.wav has 0.84s (expected 1.0)
# Processing testing:  91%|█████████ | 163/180 [00:12<00:01, 13.70it/s]
# Duration mismatch: other_sheila.06076b6b_nohash_0.wav has 0.98s (expected 1.0)
# Processing testing:  97%|█████████▋| 175/180 [00:13<00:00, 14.12it/s]
# Duration mismatch: other_sheila.66276b0e_nohash_0.wav has 0.90s (expected 1.0)
# Duration mismatch: other_sheila.5d4e3bb8_nohash_0.wav has 0.55s (expected 1.0)
# Processing testing: 100%|██████████| 180/180 [00:14<00:00, 12.75it/s]
# Saved 178 segments to /content/dataset/sheila_0_organized/npz_features/testing_features.npz
# Class distribution: Target=60, Non-target=118
# Used 17 files from remain folder as replacements
# Removing: /content/dataset/sheila_0_organized/remain
# Removing: /content/dataset/sheila_0_organized/validation
# Removing: /content/dataset/sheila_0_organized/train_64
# Removing: /content/dataset/sheila_0_organized/train_8
# Removing: /content/dataset/sheila_0_organized/testing
# Removing: /content/dataset/sheila_0_organized/train_16
# Removing: /content/dataset/sheila_0_organized/train_1

# %% [markdown]
# Code for verifying the structure of .npz files

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

def verify_npz_files(directory="/content/dataset/sheila_0_organized/npz_features"):
    """Verify contents of .npz files in a directory."""
    npz_files = [f for f in os.listdir(directory) if f.endswith('.npz')]

    if not npz_files:
        print(f"No .npz files found in {directory}!")
        return

    print(f"Found {len(npz_files)} .npz files in {directory}:\n")

    for file in sorted(npz_files):
        filepath = os.path.join(directory, file)
        data = np.load(filepath)

        print(f"File: {file}")
        print(f"Number of arrays stored: {len(data.files)}\n")

        for array_name in data.files:
            array_data = data[array_name]

            print(f"  Array: '{array_name}'")
            if(array_name=='features'):
              print(f"    - Shape: {array_data.shape}")
              print(f"    - Dtype: {array_data.dtype}")
              print(f"    - Min: {np.min(array_data):.4f}, Max: {np.max(array_data):.4f}, Mean: {np.mean(array_data):.4f}")
              print(f"    - Size: {array_data.size} elements\n")

        print("-" * 50 + "\n")

if __name__ == "__main__":
    verify_npz_files()
# Out:
# Found 6 .npz files in /content/dataset/sheila_0_organized/npz_features:
#
# File: testing_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (178, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 1.0000, Mean: 0.2515
#     - Size: 284800 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: train_16_0_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (16, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 1.0000, Mean: 0.2167
#     - Size: 25600 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: train_1_0_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (1, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.9570, Mean: 0.1766
#     - Size: 1600 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: train_64_0_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (64, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 1.0000, Mean: 0.2177
#     - Size: 102400 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: train_8_0_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (8, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 1.0000, Mean: 0.2326
#     - Size: 12800 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: validation_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (178, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 1.0000, Mean: 0.2552
#     - Size: 284800 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------

# %% [markdown]
# Bestmatching

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import math

import sys

import random
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

import shutil
tfk = tf.keras
tfkl = tf.keras.layers

print(tf.__version__)

seed = 22

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

dv_model=None
auth_class=0

def cosine_similarity(vec1, vec2):
  dot_product = np.dot(vec1, vec2)
  norm_vec1 = np.linalg.norm(vec1)
  norm_vec2 = np.linalg.norm(vec2)
  return dot_product / (norm_vec1 * norm_vec2)

def compute_similarity(input_vector, d_vectors):
  similarities = []

  for dv in d_vectors:
    similarity = cosine_similarity(input_vector, dv)
    similarities.append(similarity)

  return max(similarities)

def predictDVector(d_vectors,authlabel,input_data, input_labels, threshold, verbose=True):
  input_vectors = dv_model.predict(input_data)
  total = len(input_vectors)
  total_auth = 0
  total_denied = 0

  for i in range(len(input_labels)):
    if(input_labels[i]!=auth_class):
      total_denied = total_denied+1
    else:
      total_auth = total_auth + 1

  correct_auth=0
  correct_denied=0

  for i in range(len(input_vectors)):
    similarity=compute_similarity(input_vectors[i], d_vectors)
    result = " -- ERROR!"
    if(similarity>threshold and input_labels[i] == authlabel):
      correct_auth = correct_auth + 1
      result = ""
    if(similarity<=threshold and input_labels[i] != authlabel):
      correct_denied = correct_denied + 1
      result = ""
    if(verbose):
      print("similarity: " + str(similarity) + " --- Class: " + str(input_labels[i]) + " " + result)
  correct = correct_auth + correct_denied

  print('-----------------------')
  print(" --- Testing Results ---")
  true_positive = correct_auth
  false_positive = total_denied - correct_denied
  false_negative = total_auth - correct_auth
  prec = true_positive / (true_positive + false_positive)
  recall = true_positive / (true_positive + false_negative)

  print("True Positive Rate: " + str(correct_auth) + "/" + str(total_auth) + " (" + str(correct_auth*100/total_auth) + "%)")
  print("False Positive Rate: " + str(false_positive) + "/" + str(total_denied) + " (" + str((false_positive)*100/total_denied) + "%)")
  print("Precision: " + str(prec))
  print("Recall: " + str(recall))
  print('******************')
  print("Total correct " + str(correct) + "/" + str(total))
  acc = correct/total
  f1score = 2*prec*recall/(prec+recall)
  print("Accuracy on this dataset: " + str(acc))
  print("F1-Score on this dataset: " + str(f1score))

  return acc, f1score

def provide_predictions(d_vectors, input_data):
  y_predictions_prob = np.zeros((len(input_data), 1))
  input_vectors = dv_model.predict(input_data)
  for i in range(len(input_vectors)):
    similarity=compute_similarity(input_vectors[i], d_vectors)
    y_predictions_prob[i] = similarity
  return y_predictions_prob

def evaluate_model(auth_class, train_size):
  print("Testing with speaker id: " + str(auth_class) + " and train size: " + str(train_size))

  train_dir = f"dataset/sheila_0_organized/npz_features/train_{train_size}_{auth_class}_features.npz"
  training_npz = np.load(train_dir)
  x_train = training_npz['features']

  val_dir = "dataset/sheila_0_organized/npz_features/validation_features.npz"
  validation_npz = np.load(val_dir)
  x_val, y_val = validation_npz['features'], validation_npz['labels']

  print("Validation class distribution:", np.unique(y_val, return_counts=True))

  testing_dir = "dataset/sheila_0_organized/npz_features/testing_features.npz"
  testing_npz = np.load(testing_dir)
  x_test, y_test = testing_npz['features'], testing_npz['labels']

  print("=== Dataset Summary ===")
  print(f"Training: {len(x_train)} samples (should include both classes)")
  print(f"Validation: {len(x_val)} samples - Classes: {np.unique(y_val, return_counts=True)}")
  print(f"Testing: {len(x_test)} samples - Classes: {np.unique(y_test, return_counts=True)}")

  d_vectors = dv_model.predict(x_train.reshape(train_size,40,40,1))
  print(d_vectors.shape)
  norms=np.linalg.norm(d_vectors, axis=1, keepdims=True)
  norms[norms==0]=1.0
  d_vectors=d_vectors/norms

  save_path = f"d_vectors_{auth_class}_{train_size}.npz"
  np.savez(save_path, labels=y_val, d_vectors=d_vectors)
  print(f"Saved d_vectors and labels to {save_path}")

  y_pred_prob = provide_predictions(d_vectors, x_val)

  y_val_bin = np.where(y_val == auth_class, 1, 0)

  for i,classvalue in enumerate(y_val):
    if(classvalue!=auth_class):
      y_val_bin[i] = 0

  if len(np.unique(y_val_bin)) > 1:
    fpr, tpr, thresholds = roc_curve(y_val_bin, y_pred_prob)
    roc_auc = auc(fpr, tpr)
    print("-----")

    print("Plotting the Receiving Operating Characteristic curve:")
    '''
    # Plot ROC curve
    plt.plot(fpr, tpr, 'b', label='AUC = %0.2f'% roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'r--')
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    '''
    fnr = 1 - tpr
    try:
      eer_threshold = thresholds[np.nanargmin(np.absolute((fnr - fpr)))]
      print("-----")
      print("EER Threshold: ", eer_threshold)
      abs_diffs = np.abs(fpr - fnr)
      min_index = np.argmin(abs_diffs)
      EER = np.mean((fpr[min_index], fnr[min_index]))
    except:
      eer_threshold=0.5
      EER=1.0
      print(print("Warning: EER calculation failed - using default threshold"))

  else:
    print("Warning: Only one class present in validation data")
    eer_threshold = 0.5
    EER = 1.0
    roc_auc = 0.5
    print("EER = " + str(EER))
    print("AUC = " + str(roc_auc))

  acc, f1score = predictDVector(d_vectors, auth_class, x_test, y_test, threshold=eer_threshold, verbose=False)

  with open("test-results-td-bestmatch.txt", "a") as f:
      f.write(f"Speaker {auth_class} | Train Size: {train_size}\n")
      f.write(f"Accuracy: {acc:.4f} | F1: {f1score:.4f} | EER: {EER:.4f} | AUC: {roc_auc:.4f}\n")
      f.close

def main():
    auth_class = 0
    train_sizes = [1, 8, 16, 64]

    global dv_model

    d_vector_model_name = "dvector_student_model.h5"
    dv_model = tfk.models.load_model(d_vector_model_name)
    dv_model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                    optimizer=tfk.optimizers.Adam(learning_rate=0.0001),
                    metrics=['accuracy'])
    dv_model.summary()
    with open("test-results-td-bestmatch.txt", "w") as f:
        f.write("Speaker Verification Results\n")
        f.write("==========================\n\n")

    for size in train_sizes:
        evaluate_model(auth_class, size)

if __name__ == "__main__":
    # !rm -r /content/d_vectors/
    main()
    # !mkdir /content/d_vectors/
    # !mv d_vectors* /content/d_vectors/
# Out:
# 2.18.0
# rm: cannot remove '/content/d_vectors/': No such file or directory
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "student_dnn_dvector"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)                   │ (None, 40, 40, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 192)                 │         307,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 192)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 192)                 │          37,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 192)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 192)                 │          37,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 192)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ d_vector (Dense)                     │ (None, 256)                 │          49,408 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 430,912 (1.64 MB)
#  Trainable params: 430,912 (1.64 MB)
#  Non-trainable params: 0 (0.00 B)
# Testing with speaker id: 0 and train size: 1
# Validation class distribution: (array([-1,  0], dtype=int32), array([118,  60]))
# === Dataset Summary ===
# Training: 1 samples (should include both classes)
# Validation: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# Testing: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# (1, 256)
# Saved d_vectors and labels to d_vectors_0_1.npz
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# -----
# Plotting the Receiving Operating Characteristic curve:
# -----
# EER Threshold:  0.606460690498352
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# -----------------------
#  --- Testing Results ---
# True Positive Rate: 45/60 (75.0%)
# False Positive Rate: 32/118 (27.11864406779661%)
# Precision: 0.5844155844155844
# Recall: 0.75
# ******************
# Total correct 131/178
# Accuracy on this dataset: 0.7359550561797753
# F1-Score on this dataset: 0.6569343065693432
# Testing with speaker id: 0 and train size: 8
# Validation class distribution: (array([-1,  0], dtype=int32), array([118,  60]))
# === Dataset Summary ===
# Training: 8 samples (should include both classes)
# Validation: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# Testing: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# (8, 256)
# Saved d_vectors and labels to d_vectors_0_8.npz
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# -----
# Plotting the Receiving Operating Characteristic curve:
# -----
# EER Threshold:  0.8827264308929443
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# -----------------------
#  --- Testing Results ---
# True Positive Rate: 55/60 (91.66666666666667%)
# False Positive Rate: 3/118 (2.542372881355932%)
# Precision: 0.9482758620689655
# Recall: 0.9166666666666666
# ******************
# Total correct 170/178
# Accuracy on this dataset: 0.9550561797752809
# F1-Score on this dataset: 0.9322033898305084
# Testing with speaker id: 0 and train size: 16
# Validation class distribution: (array([-1,  0], dtype=int32), array([118,  60]))
# === Dataset Summary ===
# Training: 16 samples (should include both classes)
# Validation: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# Testing: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# (16, 256)
# Saved d_vectors and labels to d_vectors_0_16.npz
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# -----
# Plotting the Receiving Operating Characteristic curve:
# -----
# EER Threshold:  0.8887898325920105
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# -----------------------
#  --- Testing Results ---
# True Positive Rate: 57/60 (95.0%)
# False Positive Rate: 1/118 (0.847457627118644%)
# Precision: 0.9827586206896551
# Recall: 0.95
# ******************
# Total correct 174/178
# Accuracy on this dataset: 0.9775280898876404
# F1-Score on this dataset: 0.9661016949152542
# Testing with speaker id: 0 and train size: 64
# Validation class distribution: (array([-1,  0], dtype=int32), array([118,  60]))
# === Dataset Summary ===
# Training: 64 samples (should include both classes)
# Validation: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# Testing: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# (64, 256)
# Saved d_vectors and labels to d_vectors_0_64.npz
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# -----
# Plotting the Receiving Operating Characteristic curve:
# -----
# EER Threshold:  0.9007431864738464
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# -----------------------
#  --- Testing Results ---
# True Positive Rate: 60/60 (100.0%)
# False Positive Rate: 3/118 (2.542372881355932%)
# Precision: 0.9523809523809523
# Recall: 1.0
# ******************
# Total correct 175/178
# Accuracy on this dataset: 0.9831460674157303
# F1-Score on this dataset: 0.975609756097561
# mv: cannot move 'd_vectors' to a subdirectory of itself, '/content/d_vectors/d_vectors'

# %% [markdown]
# Mean Cos

# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import roc_curve, auc
import sys

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
seed = 22
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

print(tf.__version__)

def cosine_similarity(vec1, vec2):
    """Compute cosine similarity between two vectors"""
    dot_product = np.dot(vec1, vec2)
    norm_product = np.linalg.norm(vec1) * np.linalg.norm(vec2)
    return dot_product / (norm_product + 1e-8)

def compute_mean_d_vector(d_vectors):
    """Compute the mean d-vector from enrollment samples"""
    return np.mean(d_vectors, axis=0)

def predictDVector(mean_d_vector, authlabel, input_data, input_labels, threshold, verbose=True):
    """Evaluate performance using mean cosine similarity"""
    input_vectors = dv_model.predict(input_data)
    total = len(input_vectors)

    is_target = (input_labels == authlabel)
    total_auth = np.sum(is_target)
    total_denied = total - total_auth

    similarities = np.array([cosine_similarity(vec, mean_d_vector) for vec in input_vectors])
    predictions = similarities > threshold

    true_pos = np.sum(predictions & is_target)
    true_neg = np.sum(~predictions & ~is_target)
    false_pos = np.sum(predictions & ~is_target)
    false_neg = np.sum(~predictions & is_target)

    with np.errstate(divide='ignore', invalid='ignore'):
        prec = true_pos / (true_pos + false_pos) if (true_pos + false_pos) > 0 else 0
        recall = true_pos / total_auth if total_auth > 0 else 0
        f1 = 2 * (prec * recall) / (prec + recall) if (prec + recall) > 0 else 0
        acc = (true_pos + true_neg) / total
        fpr = false_pos / total_denied if total_denied > 0 else 0

    print('-----------------------')
    print(" --- Testing Results ---")
    print(f"Target samples: {total_auth}/{total}")
    print(f"Non-target samples: {total_denied}/{total}")
    print(f"True Positive Rate: {true_pos}/{total_auth} ({true_pos/total_auth*100:.1f}%)")
    print(f"False Positive Rate: {false_pos}/{total_denied} (N/A)" if total_denied == 0 else
          f"False Positive Rate: {false_pos}/{total_denied} ({false_pos/total_denied*100:.1f}%)")
    print(f"Precision: {prec:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")
    print(f"Accuracy: {acc:.4f}")

    return acc, f1

def provide_predictions(mean_d_vector, input_data):
    """Generate similarity predictions using mean d-vector"""
    input_vectors = dv_model.predict(input_data)
    return np.array([cosine_similarity(vec, mean_d_vector) for vec in input_vectors])

def evaluate_model(auth_class, train_size):
    """Complete evaluation pipeline for mean cosine approach"""
    print(f"\nEvaluating speaker {auth_class} with {train_size} enrollment samples (Mean Cosine)")

    try:
        train_dir = f"dataset/user_0_organized/npz_features/train_{train_size}_{auth_class}_features.npz"
        training_npz = np.load(train_dir)
        x_train = training_npz['features']

        val_dir = "dataset/user_0_organized/npz_features/validation_features.npz"
        validation_npz = np.load(val_dir)
        x_val, y_val = validation_npz['features'], validation_npz['labels']

        testing_dir = "dataset/user_0_organized/npz_features/testing_features.npz"
        testing_npz = np.load(testing_dir)
        x_test, y_test = testing_npz['features'], testing_npz['labels']

        print("=== Dataset Summary ===")
        print(f"Training: {len(x_train)} samples")
        print(f"Validation: {len(x_val)} samples - Classes: {np.unique(y_val, return_counts=True)}")
        print(f"Testing: {len(x_test)} samples - Classes: {np.unique(y_test, return_counts=True)}")

        d_vectors = dv_model.predict(x_train.reshape(-1, 40, 40, 1))
        mean_d_vector = compute_mean_d_vector(d_vectors)
        print(f"Mean D-Vector computed using {len(d_vectors)} samples")

        y_pred_prob = provide_predictions(mean_d_vector, x_val.reshape(-1, 40, 40, 1))
        y_val_bin = (y_val == auth_class).astype(int)

        if len(np.unique(y_val_bin)) > 1:
            fpr, tpr, thresholds = roc_curve(y_val_bin, y_pred_prob)
            roc_auc = auc(fpr, tpr)

            fnr = 1 - tpr
            try:
                eer_threshold = thresholds[np.nanargmin(np.absolute((fnr - fpr)))]
                abs_diffs = np.abs(fpr - fnr)
                min_index = np.argmin(abs_diffs)
                EER = np.mean((fpr[min_index], fnr[min_index]))
            except:
                eer_threshold = 0.5
                EER = 1.0
                print("Warning: EER calculation failed - using default threshold")
        else:
            print("Warning: Only one class present in validation data")
            eer_threshold = 0.5
            EER = 1.0
            roc_auc = 0.5

        acc, f1score = predictDVector(mean_d_vector, auth_class,
                                    x_test.reshape(-1, 40, 40, 1), y_test,
                                    threshold=eer_threshold, verbose=False)

        with open("test-results-td-meancos.txt", "a") as f:
            f.write(f"Speaker {auth_class} | Train Size: {train_size}\n")
            f.write(f"Accuracy: {acc:.4f} | F1: {f1score:.4f} ")
            f.write(f"| EER: {EER:.4f} | AUC: {roc_auc:.4f}\n\n")

        return acc, f1score, EER, roc_auc

    except Exception as e:
        print(f"Error in evaluation: {e}")
        return 0, 0, 1, 0

def main():
    auth_class = 0
    train_sizes = [1, 8, 16, 64]

    global dv_model
    d_vector_model_name = "d-vector-extractor-256.h5"
    dv_model = tf.keras.models.load_model(d_vector_model_name)
    dv_model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
                    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                    metrics=['accuracy'])

    with open("test-results-td-meancos.txt", "w") as f:
        f.write("Speaker Verification Results (Mean Cosine)\n")
        f.write("========================================\n\n")

    for size in train_sizes:
        evaluate_model(auth_class, size)

if __name__ == "__main__":
    main()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2.18.0
#
# Evaluating speaker 0 with 1 enrollment samples (Mean Cosine)
# === Dataset Summary ===
# Training: 1 samples
# Validation: 177 samples - Classes: (array([-1,  0], dtype=int32), array([115,  62]))
# Testing: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Mean D-Vector computed using 1 samples
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# -----------------------
#  --- Testing Results ---
# Target samples: 60/178
# Non-target samples: 118/178
# True Positive Rate: 41/60 (68.3%)
# False Positive Rate: 23/118 (19.5%)
# Precision: 0.6406
# Recall: 0.6833
# F1-Score: 0.6613
# Accuracy: 0.7640
#
# Evaluating speaker 0 with 8 enrollment samples (Mean Cosine)
# === Dataset Summary ===
# Training: 8 samples
# Validation: 177 samples - Classes: (array([-1,  0], dtype=int32), array([115,  62]))
# Testing: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Mean D-Vector computed using 8 samples
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# -----------------------
#  --- Testing Results ---
# Target samples: 60/178
# Non-target samples: 118/178
# True Positive Rate: 41/60 (68.3%)
# False Positive Rate: 23/118 (19.5%)
# Precision: 0.6406
# Recall: 0.6833
# F1-Score: 0.6613
# Accuracy: 0.7640
#
# Evaluating speaker 0 with 16 enrollment samples (Mean Cosine)
# === Dataset Summary ===
# Training: 16 samples
# Validation: 177 samples - Classes: (array([-1,  0], dtype=int32), array([115,  62]))
# Testing: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Mean D-Vector computed using 16 samples
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# -----------------------
#  --- Testing Results ---
# Target samples: 60/178
# Non-target samples: 118/178
# True Positive Rate: 44/60 (73.3%)
# False Positive Rate: 14/118 (11.9%)
# Precision: 0.7586
# Recall: 0.7333
# F1-Score: 0.7458
# Accuracy: 0.8315
#
# Evaluating speaker 0 with 64 enrollment samples (Mean Cosine)
# === Dataset Summary ===
# Training: 64 samples
# Validation: 177 samples - Classes: (array([-1,  0], dtype=int32), array([115,  62]))
# Testing: 178 samples - Classes: (array([-1,  0], dtype=int32), array([118,  60]))
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Mean D-Vector computed using 64 samples
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# -----------------------
#  --- Testing Results ---
# Target samples: 60/178
# Non-target samples: 118/178
# True Positive Rate: 45/60 (75.0%)
# False Positive Rate: 15/118 (12.7%)
# Precision: 0.7500
# Recall: 0.7500
# F1-Score: 0.7500
# Accuracy: 0.8315

# %% [markdown]
# Inspect .npz structure

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

def verify_npz_files(directory="/content/d_vectors/"):
    """Verify contents of .npz files in a directory."""
    npz_files = [f for f in os.listdir(directory) if f.endswith('.npz')]

    if not npz_files:
        print(f"No .npz files found in {directory}!")
        return

    print(f"Found {len(npz_files)} .npz files in {directory}:\n")

    for file in sorted(npz_files):
        filepath = os.path.join(directory, file)
        data = np.load(filepath)

        print(f"File: {file}")
        print(f"Number of arrays stored: {len(data.files)}\n")

        for array_name in data.files:
            array_data = data[array_name]

            print(f"  Array: '{array_name}'")
            if(array_name=='d_vectors'):
              print(f"    - Shape: {array_data.shape}")
              print(f"    - Dtype: {array_data.dtype}")
              print(f"    - Min: {np.min(array_data):.4f}, Max: {np.max(array_data):.4f}, Mean: {np.mean(array_data):.4f}")
              print(f"    - Size: {array_data.size} elements\n")

        print("-" * 50 + "\n")

if __name__ == "__main__":
    verify_npz_files()
# Out:
# Found 4 .npz files in /content/d_vectors/:
#
# File: d_vectors_0_1.npz
# Number of arrays stored: 2
#
#   Array: 'labels'
#   Array: 'd_vectors'
#     - Shape: (1, 256)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.1976, Mean: 0.0407
#     - Size: 256 elements
#
# --------------------------------------------------
#
# File: d_vectors_0_16.npz
# Number of arrays stored: 2
#
#   Array: 'labels'
#   Array: 'd_vectors'
#     - Shape: (16, 256)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.2419, Mean: 0.0417
#     - Size: 4096 elements
#
# --------------------------------------------------
#
# File: d_vectors_0_64.npz
# Number of arrays stored: 2
#
#   Array: 'labels'
#   Array: 'd_vectors'
#     - Shape: (64, 256)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.2518, Mean: 0.0419
#     - Size: 16384 elements
#
# --------------------------------------------------
#
# File: d_vectors_0_8.npz
# Number of arrays stored: 2
#
#   Array: 'labels'
#   Array: 'd_vectors'
#     - Shape: (8, 256)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.2359, Mean: 0.0416
#     - Size: 2048 elements
#
# --------------------------------------------------

# %% [markdown]
# Convert .npz file generated in a C header

# %%
import numpy as np
import os

def sanitize_name(name):
    """Sanitize array name for C variable naming."""
    return name.replace('.', '_').replace('-', '_')+"_SV"

def generate_npz_header(npz_dir="/content/d_vectors", output_file="d_vectors_dense.h"):
    """Generate a C header with 2D arrays (samples x 256) from .npz files"""
    npz_files = [f for f in os.listdir(npz_dir) if f.endswith('.npz')]

    with open(output_file, "w") as f:
        f.write("#ifndef D_VECTORS_DENSE_H\n")
        f.write("#define D_VECTORS_H\n\n")
        f.write("#include <stddef.h>\n\n")

        for file in sorted(npz_files):
            file_path = os.path.join(npz_dir, file)
            with np.load(file_path) as data:
                if 'd_vectors' not in data:
                    continue

                d_vectors = data['d_vectors']
                if d_vectors.ndim != 2 or d_vectors.shape[1] != 256:
                    continue

                array_name = sanitize_name(os.path.splitext(file)[0])
                samples = d_vectors.shape[0]
                f.write(f"// {samples} samples of 256-dimensional vectors\n")
                f.write(f"static const float {array_name}[{samples}][256] = {{\n")
                for sample in d_vectors:
                    f.write("    {")
                    line = ", ".join(f"{x:.6f}f" for x in sample)
                    f.write(line)
                    f.write("},\n")

                f.write("};\n\n")

        f.write("#endif // D_VECTORS_DENSE_H\n")

if __name__ == "__main__":
    generate_npz_header()
