# %% [markdown]
# Dataset Extraction

# %%
# !rm -r /content/dataset
# !unzip dataset.zip
# !rm -r __MACOSX
# Out:
# Archive:  dataset.zip
#    creating: dataset/
#   inflating: __MACOSX/._dataset
#   inflating: dataset/.DS_Store
#   inflating: __MACOSX/dataset/._.DS_Store
#    creating: dataset/others/
#    creating: dataset/user_0/
#   inflating: dataset/others/yes.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._yes.0a196374_nohash_1.wav
#   inflating: dataset/others/backward.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._backward.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/cat.0e6e36c9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.0e6e36c9_nohash_0.wav
#   inflating: dataset/others/down.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._down.0a2b400e_nohash_3.wav
#   inflating: dataset/others/seven.0a0b46ae_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._seven.0a0b46ae_nohash_0.wav
#   inflating: dataset/others/stop.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._stop.0a196374_nohash_2.wav
#   inflating: dataset/others/go.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._go.0a196374_nohash_1.wav
#   inflating: dataset/others/backward.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._backward.0a5636ca_nohash_0.wav
#   inflating: dataset/others/sheila.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._sheila.0a196374_nohash_0.wav
#   inflating: dataset/others/no.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._no.0a2b400e_nohash_0.wav
#   inflating: dataset/others/yes.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._yes.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/down.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._down.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/seven.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._seven.0a196374_nohash_0.wav
#   inflating: dataset/others/eight.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._eight.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/off.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._off.0a2b400e_nohash_3.wav
#   inflating: dataset/others/nine.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._nine.0a196374_nohash_0.wav
#   inflating: dataset/others/go.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._go.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/forward.1a994c9f_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._forward.1a994c9f_nohash_1.wav
#   inflating: dataset/others/nine.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._nine.0a2b400e_nohash_4.wav
#   inflating: dataset/others/house.0a396ff2_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._house.0a396ff2_nohash_0.wav
#   inflating: dataset/others/happy.0b09edd3_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._happy.0b09edd3_nohash_0.wav
#   inflating: dataset/others/visual.0b57a6ed_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._visual.0b57a6ed_nohash_0.wav
#   inflating: dataset/others/go.0a9f9af7_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._go.0a9f9af7_nohash_1.wav
#   inflating: dataset/others/nine.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._nine.0a196374_nohash_1.wav
#   inflating: dataset/others/off.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._off.0a2b400e_nohash_2.wav
#   inflating: dataset/others/eight.0ab3b47d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._eight.0ab3b47d_nohash_1.wav
#   inflating: dataset/others/learn.0b57a6ed_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._learn.0b57a6ed_nohash_0.wav
#   inflating: dataset/others/seven.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._seven.0a196374_nohash_1.wav
#   inflating: dataset/others/yes.0a9f9af7_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._yes.0a9f9af7_nohash_1.wav
#   inflating: dataset/others/go.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._go.0a2b400e_nohash_4.wav
#   inflating: dataset/others/no.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._no.0a2b400e_nohash_1.wav
#   inflating: dataset/others/nine.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._nine.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/dog.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._dog.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/go.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._go.0a196374_nohash_0.wav
#   inflating: dataset/others/down.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._down.0a2b400e_nohash_2.wav
#   inflating: dataset/others/seven.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._seven.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/backward.0b7ee1a0_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._backward.0b7ee1a0_nohash_1.wav
#   inflating: dataset/others/yes.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._yes.0a196374_nohash_0.wav
#   inflating: dataset/others/backward.0b7ee1a0_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._backward.0b7ee1a0_nohash_3.wav
#   inflating: dataset/others/yes.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._yes.0a196374_nohash_2.wav
#   inflating: dataset/others/down.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._down.0a2b400e_nohash_0.wav
#   inflating: dataset/others/go.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._go.0a196374_nohash_2.wav
#   inflating: dataset/others/stop.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._stop.0a196374_nohash_1.wav
#   inflating: dataset/others/no.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._no.0a2b400e_nohash_3.wav
#   inflating: dataset/others/sheila.0c09f202_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._sheila.0c09f202_nohash_0.wav
#   inflating: dataset/others/seven.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._seven.0a196374_nohash_3.wav
#   inflating: dataset/others/off.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._off.0a2b400e_nohash_0.wav
#   inflating: dataset/others/follow.0b139000_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._follow.0b139000_nohash_0.wav
#   inflating: dataset/others/forward.1a994c9f_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._forward.1a994c9f_nohash_2.wav
#   inflating: dataset/others/forward.1a994c9f_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._forward.1a994c9f_nohash_3.wav
#   inflating: dataset/others/off.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._off.0a2b400e_nohash_1.wav
#   inflating: dataset/others/nine.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._nine.0a196374_nohash_2.wav
#   inflating: dataset/others/seven.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._seven.0a196374_nohash_2.wav
#   inflating: dataset/others/yes.0a9f9af7_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._yes.0a9f9af7_nohash_2.wav
#   inflating: dataset/others/stop.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._stop.0a2b400e_nohash_4.wav
#   inflating: dataset/others/no.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._no.0a2b400e_nohash_2.wav
#   inflating: dataset/others/up.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._up.0a5636ca_nohash_0.wav
#   inflating: dataset/others/stop.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._stop.0a196374_nohash_0.wav
#   inflating: dataset/others/go.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._go.0a196374_nohash_3.wav
#   inflating: dataset/others/down.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._down.0a2b400e_nohash_1.wav
#   inflating: dataset/others/tree.0c2ca723_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0c2ca723_nohash_0.wav
#   inflating: dataset/others/tree.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0a196374_nohash_0.wav
#   inflating: dataset/others/yes.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._yes.0a196374_nohash_3.wav
#   inflating: dataset/others/up.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._up.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/backward.0b7ee1a0_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._backward.0b7ee1a0_nohash_2.wav
#   inflating: dataset/others/down.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._down.0a196374_nohash_1.wav
#   inflating: dataset/others/zero.0b7ee1a0_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._zero.0b7ee1a0_nohash_2.wav
#   inflating: dataset/others/yes.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._yes.0a2b400e_nohash_3.wav
#   inflating: dataset/others/no.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._no.0a196374_nohash_2.wav
#   inflating: dataset/others/nine.0a7c2a8d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._nine.0a7c2a8d_nohash_1.wav
#   inflating: dataset/others/go.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._go.0a2b400e_nohash_3.wav
#   inflating: dataset/others/stop.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._stop.0a2b400e_nohash_0.wav
#   inflating: dataset/others/bed.0b77ee66_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._bed.0b77ee66_nohash_2.wav
#   inflating: dataset/others/yes.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._yes.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/down.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._down.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/seven.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._seven.0a2b400e_nohash_2.wav
#   inflating: dataset/others/marvin.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._marvin.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/forward.1b42b551_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._forward.1b42b551_nohash_1.wav
#   inflating: dataset/others/.DS_Store
#   inflating: __MACOSX/dataset/others/._.DS_Store
#   inflating: dataset/others/forward.1b18600d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._forward.1b18600d_nohash_0.wav
#   inflating: dataset/others/nine.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._nine.0a2b400e_nohash_2.wav
#   inflating: dataset/others/marvin.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._marvin.0a5636ca_nohash_0.wav
#   inflating: dataset/others/off.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._off.0a196374_nohash_1.wav
#   inflating: dataset/others/sheila.0aad3227_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._sheila.0aad3227_nohash_0.wav
#   inflating: dataset/others/tree.0c2d2ffa_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0c2d2ffa_nohash_0.wav
#   inflating: dataset/others/cat.0d90d8e1_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.0d90d8e1_nohash_0.wav
#   inflating: dataset/others/house.0b56bcfe_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._house.0b56bcfe_nohash_1.wav
#   inflating: dataset/others/house.0b56bcfe_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._house.0b56bcfe_nohash_0.wav
#   inflating: dataset/others/off.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._off.0a196374_nohash_0.wav
#   inflating: dataset/others/marvin.0a5636ca_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._marvin.0a5636ca_nohash_1.wav
#   inflating: dataset/others/nine.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._nine.0a2b400e_nohash_3.wav
#   inflating: dataset/others/off.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._off.0a2b400e_nohash_4.wav
#   inflating: dataset/others/visual.0b139000_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._visual.0b139000_nohash_0.wav
#   inflating: dataset/others/forward.1b18600d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._forward.1b18600d_nohash_1.wav
#   inflating: dataset/others/forward.1b42b551_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._forward.1b42b551_nohash_0.wav
#   inflating: dataset/others/cat.0d82fd99_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.0d82fd99_nohash_0.wav
#   inflating: dataset/others/seven.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._seven.0a2b400e_nohash_3.wav
#   inflating: dataset/others/learn.0b139000_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._learn.0b139000_nohash_0.wav
#   inflating: dataset/others/down.0a9f9af7_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._down.0a9f9af7_nohash_1.wav
#   inflating: dataset/others/bed.0d82fd99_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bed.0d82fd99_nohash_0.wav
#   inflating: dataset/others/stop.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._stop.0a2b400e_nohash_1.wav
#   inflating: dataset/others/go.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._go.0a2b400e_nohash_2.wav
#   inflating: dataset/others/no.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._no.0a196374_nohash_3.wav
#   inflating: dataset/others/nine.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._nine.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/seven.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._seven.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/yes.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._yes.0a2b400e_nohash_2.wav
#   inflating: dataset/others/down.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._down.0a2b400e_nohash_4.wav
#   inflating: dataset/others/bed.0b56bcfe_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bed.0b56bcfe_nohash_0.wav
#   inflating: dataset/others/down.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._down.0a196374_nohash_0.wav
#   inflating: dataset/others/house.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._house.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/down.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._down.0a196374_nohash_2.wav
#   inflating: dataset/others/yes.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._yes.0a2b400e_nohash_0.wav
#   inflating: dataset/others/zero.0b7ee1a0_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._zero.0b7ee1a0_nohash_1.wav
#   inflating: dataset/others/nine.0a7c2a8d_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._nine.0a7c2a8d_nohash_2.wav
#   inflating: dataset/others/no.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._no.0a196374_nohash_1.wav
#   inflating: dataset/others/go.0a196374_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._go.0a196374_nohash_4.wav
#   inflating: dataset/others/stop.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._stop.0a2b400e_nohash_3.wav
#   inflating: dataset/others/bird.0b40aa8e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bird.0b40aa8e_nohash_0.wav
#   inflating: dataset/others/go.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._go.0a2b400e_nohash_0.wav
#   inflating: dataset/others/bed.0b77ee66_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._bed.0b77ee66_nohash_1.wav
#   inflating: dataset/others/seven.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._seven.0a2b400e_nohash_1.wav
#   inflating: dataset/others/tree.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/forward.1b42b551_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._forward.1b42b551_nohash_2.wav
#   inflating: dataset/others/five.0a396ff2_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._five.0a396ff2_nohash_1.wav
#   inflating: dataset/others/forward.1a994c9f_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._forward.1a994c9f_nohash_4.wav
#   inflating: dataset/others/cat.0cd323ec_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.0cd323ec_nohash_0.wav
#   inflating: dataset/others/no.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._no.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/off.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._off.0a196374_nohash_2.wav
#   inflating: dataset/others/nine.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._nine.0a2b400e_nohash_1.wav
#   inflating: dataset/others/wow.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._wow.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/wow.0ab3b47d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._wow.0ab3b47d_nohash_1.wav
#   inflating: dataset/others/nine.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._nine.0a2b400e_nohash_0.wav
#   inflating: dataset/others/tree.0ac15fe9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0ac15fe9_nohash_0.wav
#   inflating: dataset/others/off.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._off.0a196374_nohash_3.wav
#   inflating: dataset/others/no.0a9f9af7_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._no.0a9f9af7_nohash_1.wav
#   inflating: dataset/others/forward.1b18600d_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._forward.1b18600d_nohash_2.wav
#   inflating: dataset/others/five.0a396ff2_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._five.0a396ff2_nohash_0.wav
#   inflating: dataset/others/forward.1b42b551_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._forward.1b42b551_nohash_3.wav
#   inflating: dataset/others/house.0b77ee66_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._house.0b77ee66_nohash_0.wav
#   inflating: dataset/others/seven.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._seven.0a2b400e_nohash_0.wav
#   inflating: dataset/others/stop.0ac15fe9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._stop.0ac15fe9_nohash_0.wav
#   inflating: dataset/others/down.0a9f9af7_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._down.0a9f9af7_nohash_2.wav
#   inflating: dataset/others/no.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._no.0a2b400e_nohash_4.wav
#   inflating: dataset/others/bed.0b77ee66_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bed.0b77ee66_nohash_0.wav
#   inflating: dataset/others/go.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._go.0a2b400e_nohash_1.wav
#   inflating: dataset/others/bird.0b40aa8e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._bird.0b40aa8e_nohash_1.wav
#   inflating: dataset/others/stop.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._stop.0a2b400e_nohash_2.wav
#   inflating: dataset/others/no.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._no.0a196374_nohash_0.wav
#   inflating: dataset/others/sheila.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._sheila.0a2b400e_nohash_0.wav
#   inflating: dataset/others/zero.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._zero.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/yes.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._yes.0a2b400e_nohash_1.wav
#   inflating: dataset/others/backward.0b7ee1a0_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._backward.0b7ee1a0_nohash_4.wav
#   inflating: dataset/others/down.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._down.0a196374_nohash_3.wav
#   inflating: dataset/others/learn.0b7ee1a0_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._learn.0b7ee1a0_nohash_1.wav
#   inflating: dataset/others/right.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._right.0a196374_nohash_0.wav
#   inflating: dataset/others/four.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._four.0a2b400e_nohash_2.wav
#   inflating: dataset/others/visual.0b7ee1a0_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._visual.0b7ee1a0_nohash_1.wav
#   inflating: dataset/others/wow.0a5636ca_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._wow.0a5636ca_nohash_1.wav
#   inflating: dataset/others/cat.0bfec55f_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.0bfec55f_nohash_0.wav
#   inflating: dataset/others/four.0ac15fe9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._four.0ac15fe9_nohash_0.wav
#   inflating: dataset/others/sheila.0b09edd3_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._sheila.0b09edd3_nohash_0.wav
#   inflating: dataset/others/sheila.0b40aa8e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._sheila.0b40aa8e_nohash_1.wav
#   inflating: dataset/others/left.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._left.0a5636ca_nohash_0.wav
#   inflating: dataset/others/zero.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._zero.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/left.0a5636ca_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._left.0a5636ca_nohash_1.wav
#   inflating: dataset/others/sheila.0b09edd3_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._sheila.0b09edd3_nohash_1.wav
#   inflating: dataset/others/sheila.0b40aa8e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._sheila.0b40aa8e_nohash_0.wav
#   inflating: dataset/others/right.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._right.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/cat.0bfec55f_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._cat.0bfec55f_nohash_1.wav
#   inflating: dataset/others/wow.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._wow.0a5636ca_nohash_0.wav
#   inflating: dataset/others/happy.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._happy.0a196374_nohash_0.wav
#   inflating: dataset/others/follow.0b7ee1a0_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._follow.0b7ee1a0_nohash_4.wav
#   inflating: dataset/others/visual.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._visual.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/four.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._four.0a2b400e_nohash_3.wav
#   inflating: dataset/others/cat.0c540988_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.0c540988_nohash_0.wav
#   inflating: dataset/others/right.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._right.0a196374_nohash_1.wav
#   inflating: dataset/others/visual.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._visual.0a5636ca_nohash_0.wav
#   inflating: dataset/others/learn.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._learn.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/bed.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bed.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/learn.0b7ee1a0_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._learn.0b7ee1a0_nohash_2.wav
#   inflating: dataset/others/right.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._right.0a196374_nohash_3.wav
#   inflating: dataset/others/four.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._four.0a2b400e_nohash_1.wav
#   inflating: dataset/others/visual.0b7ee1a0_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._visual.0b7ee1a0_nohash_2.wav
#   inflating: dataset/others/bird.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bird.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/bed.0bde966a_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._bed.0bde966a_nohash_1.wav
#   inflating: dataset/others/tree.0b40aa8e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0b40aa8e_nohash_0.wav
#   inflating: dataset/others/six.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._six.0a196374_nohash_0.wav
#   inflating: dataset/others/six.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._six.0a2b400e_nohash_4.wav
#   inflating: dataset/others/happy.0acc1ac5_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._happy.0acc1ac5_nohash_0.wav
#   inflating: dataset/others/house.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._house.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/six.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._six.0a196374_nohash_1.wav
#   inflating: dataset/others/tree.0b09edd3_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0b09edd3_nohash_0.wav
#   inflating: dataset/others/four.0a196374_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._four.0a196374_nohash_4.wav
#   inflating: dataset/others/bed.0bde966a_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bed.0bde966a_nohash_0.wav
#   inflating: dataset/others/bird.0a7c2a8d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._bird.0a7c2a8d_nohash_1.wav
#   inflating: dataset/others/visual.0b7ee1a0_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._visual.0b7ee1a0_nohash_3.wav
#   inflating: dataset/others/four.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._four.0a2b400e_nohash_0.wav
#   inflating: dataset/others/backward.0a396ff2_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._backward.0a396ff2_nohash_0.wav
#   inflating: dataset/others/bird.0ac15fe9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bird.0ac15fe9_nohash_0.wav
#   inflating: dataset/others/right.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._right.0a196374_nohash_2.wav
#   inflating: dataset/others/learn.0b7ee1a0_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._learn.0b7ee1a0_nohash_3.wav
#   inflating: dataset/others/six.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._six.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/marvin.0b57a6ed_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._marvin.0b57a6ed_nohash_0.wav
#   inflating: dataset/others/two.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._two.0a5636ca_nohash_0.wav
#   inflating: dataset/others/six.0a7c2a8d_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._six.0a7c2a8d_nohash_2.wav
#   inflating: dataset/others/dog.0b77ee66_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._dog.0b77ee66_nohash_0.wav
#   inflating: dataset/others/right.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._right.0a2b400e_nohash_2.wav
#   inflating: dataset/others/follow.0b7ee1a0_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._follow.0b7ee1a0_nohash_3.wav
#   inflating: dataset/others/two.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._two.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/four.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._four.0a196374_nohash_0.wav
#   inflating: dataset/others/cat.0bd689d7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.0bd689d7_nohash_0.wav
#   inflating: dataset/others/three.0b7ee1a0_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._three.0b7ee1a0_nohash_1.wav
#   inflating: dataset/others/right.0a7c2a8d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._right.0a7c2a8d_nohash_1.wav
#   inflating: dataset/others/six.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._six.0a2b400e_nohash_1.wav
#   inflating: dataset/others/up.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._up.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/four.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._four.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/tree.00b01445_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.00b01445_nohash_0.wav
#   inflating: dataset/others/up.0ab3b47d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._up.0ab3b47d_nohash_1.wav
#   inflating: dataset/others/six.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._six.0a2b400e_nohash_0.wav
#   inflating: dataset/others/happy.0ac15fe9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._happy.0ac15fe9_nohash_0.wav
#   inflating: dataset/others/three.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._three.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/right.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._right.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/four.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._four.0a196374_nohash_1.wav
#   inflating: dataset/others/on.0a5636ca_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._on.0a5636ca_nohash_2.wav
#   inflating: dataset/others/two.0b7ee1a0_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._two.0b7ee1a0_nohash_1.wav
#   inflating: dataset/others/follow.0b7ee1a0_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._follow.0b7ee1a0_nohash_2.wav
#   inflating: dataset/others/bird.0a9f9af7_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._bird.0a9f9af7_nohash_2.wav
#   inflating: dataset/others/right.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._right.0a2b400e_nohash_3.wav
#   inflating: dataset/others/six.0a7c2a8d_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._six.0a7c2a8d_nohash_3.wav
#   inflating: dataset/others/learn.0b7ee1a0_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._learn.0b7ee1a0_nohash_4.wav
#   inflating: dataset/others/six.0a7c2a8d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._six.0a7c2a8d_nohash_1.wav
#   inflating: dataset/others/right.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._right.0a2b400e_nohash_1.wav
#   inflating: dataset/others/visual.0b7ee1a0_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._visual.0b7ee1a0_nohash_4.wav
#   inflating: dataset/others/bird.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bird.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/follow.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._follow.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/on.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._on.0a5636ca_nohash_0.wav
#   inflating: dataset/others/happy.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._happy.0a2b400e_nohash_0.wav
#   inflating: dataset/others/four.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._four.0a196374_nohash_3.wav
#   inflating: dataset/others/dog.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._dog.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/three.0b7ee1a0_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._three.0b7ee1a0_nohash_2.wav
#   inflating: dataset/others/six.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._six.0a2b400e_nohash_2.wav
#   inflating: dataset/others/cat.0cb74144_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.0cb74144_nohash_0.wav
#   inflating: dataset/others/bird.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bird.0a196374_nohash_0.wav
#   inflating: dataset/others/six.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._six.0a2b400e_nohash_3.wav
#   inflating: dataset/others/bed.0c40e715_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bed.0c40e715_nohash_0.wav
#   inflating: dataset/others/four.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._four.0a196374_nohash_2.wav
#   inflating: dataset/others/eight.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._eight.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/happy.0ba018fc_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._happy.0ba018fc_nohash_0.wav
#   inflating: dataset/others/on.0a5636ca_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._on.0a5636ca_nohash_1.wav
#   inflating: dataset/others/one.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._one.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/bird.0a9f9af7_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._bird.0a9f9af7_nohash_1.wav
#   inflating: dataset/others/follow.0b7ee1a0_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._follow.0b7ee1a0_nohash_1.wav
#   inflating: dataset/others/right.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._right.0a2b400e_nohash_0.wav
#   inflating: dataset/others/bed.0cb74144_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bed.0cb74144_nohash_0.wav
#   inflating: dataset/others/six.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._six.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/one.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._one.0a5636ca_nohash_0.wav
#   inflating: dataset/others/right.0a196374_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._right.0a196374_nohash_4.wav
#   inflating: dataset/others/marvin.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._marvin.0a196374_nohash_0.wav
#   inflating: dataset/others/off.0a5636ca_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._off.0a5636ca_nohash_1.wav
#   inflating: dataset/others/dog.0ac15fe9_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._dog.0ac15fe9_nohash_1.wav
#   inflating: dataset/others/forward.1b5ba788_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._forward.1b5ba788_nohash_0.wav
#   inflating: dataset/others/bird.0a396ff2_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bird.0a396ff2_nohash_0.wav
#   inflating: dataset/others/dog.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._dog.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/marvin.0a9f9af7_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._marvin.0a9f9af7_nohash_1.wav
#   inflating: dataset/others/up.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._up.0a2b400e_nohash_0.wav
#   inflating: dataset/others/backward.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._backward.0a2b400e_nohash_2.wav
#   inflating: dataset/others/zero.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._zero.0a196374_nohash_2.wav
#   inflating: dataset/others/happy.0b77ee66_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._happy.0b77ee66_nohash_0.wav
#   inflating: dataset/others/cat.00b01445_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.00b01445_nohash_0.wav
#   inflating: dataset/others/tree.0bd689d7_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._tree.0bd689d7_nohash_1.wav
#   inflating: dataset/others/tree.0bd689d7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0bd689d7_nohash_0.wav
#   inflating: dataset/others/down.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._down.0a5636ca_nohash_0.wav
#   inflating: dataset/others/happy.0b77ee66_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._happy.0b77ee66_nohash_1.wav
#   inflating: dataset/others/zero.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._zero.0a196374_nohash_3.wav
#   inflating: dataset/others/backward.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._backward.0a2b400e_nohash_3.wav
#   inflating: dataset/others/up.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._up.0a2b400e_nohash_1.wav
#   inflating: dataset/others/marvin.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._marvin.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/off.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._off.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/forward.1b5ba788_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._forward.1b5ba788_nohash_1.wav
#   inflating: dataset/others/dog.0ac15fe9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._dog.0ac15fe9_nohash_0.wav
#   inflating: dataset/others/off.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._off.0a5636ca_nohash_0.wav
#   inflating: dataset/others/dog.0ac15fe9_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._dog.0ac15fe9_nohash_2.wav
#   inflating: dataset/others/happy.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._happy.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/up.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._up.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/backward.0ba018fc_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._backward.0ba018fc_nohash_0.wav
#   inflating: dataset/others/marvin.0a9f9af7_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._marvin.0a9f9af7_nohash_2.wav
#   inflating: dataset/others/up.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._up.0a2b400e_nohash_3.wav
#   inflating: dataset/others/zero.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._zero.0a196374_nohash_1.wav
#   inflating: dataset/others/backward.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._backward.0a2b400e_nohash_1.wav
#   inflating: dataset/others/no.0a5636ca_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._no.0a5636ca_nohash_1.wav
#   inflating: dataset/others/dog.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._dog.0a2b400e_nohash_0.wav
#   inflating: dataset/others/happy.0b56bcfe_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._happy.0b56bcfe_nohash_0.wav
#   inflating: dataset/others/bird.0b57a6ed_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bird.0b57a6ed_nohash_0.wav
#   inflating: dataset/others/dog.0ba018fc_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._dog.0ba018fc_nohash_0.wav
#   inflating: dataset/others/zero.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._zero.0a2b400e_nohash_4.wav
#   inflating: dataset/others/no.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._no.0a5636ca_nohash_0.wav
#   inflating: dataset/others/backward.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._backward.0a2b400e_nohash_0.wav
#   inflating: dataset/others/zero.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._zero.0a196374_nohash_0.wav
#   inflating: dataset/others/up.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._up.0a2b400e_nohash_2.wav
#   inflating: dataset/others/backward.0ba018fc_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._backward.0ba018fc_nohash_1.wav
#   inflating: dataset/others/up.0ac15fe9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._up.0ac15fe9_nohash_0.wav
#   inflating: dataset/others/right.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._right.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/up.0a7c2a8d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._up.0a7c2a8d_nohash_1.wav
#   inflating: dataset/others/seven.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._seven.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/nine.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._nine.0a5636ca_nohash_0.wav
#   inflating: dataset/others/bird.0b56bcfe_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bird.0b56bcfe_nohash_0.wav
#   inflating: dataset/others/seven.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._seven.0a5636ca_nohash_0.wav
#   inflating: dataset/others/sheila.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._sheila.0a5636ca_nohash_0.wav
#   inflating: dataset/others/zero.0a196374_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._zero.0a196374_nohash_4.wav
#   inflating: dataset/others/backward.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._backward.0a2b400e_nohash_4.wav
#   inflating: dataset/others/zero.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._zero.0a2b400e_nohash_0.wav
#   inflating: dataset/others/marvin.0ac15fe9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._marvin.0ac15fe9_nohash_0.wav
#   inflating: dataset/others/sheila.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._sheila.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/stop.0b7ee1a0_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._stop.0b7ee1a0_nohash_2.wav
#   inflating: dataset/others/yes.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._yes.0a5636ca_nohash_0.wav
#   inflating: dataset/others/dog.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._dog.0a196374_nohash_0.wav
#   inflating: dataset/others/zero.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._zero.0a2b400e_nohash_1.wav
#   inflating: dataset/others/go.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._go.0a5636ca_nohash_0.wav
#   inflating: dataset/others/sheila.0a5636ca_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._sheila.0a5636ca_nohash_1.wav
#   inflating: dataset/others/marvin.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._marvin.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/forward.1acc97de_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._forward.1acc97de_nohash_0.wav
#   inflating: dataset/others/tree.0bfec55f_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0bfec55f_nohash_0.wav
#   inflating: dataset/others/six.0a396ff2_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._six.0a396ff2_nohash_0.wav
#   inflating: dataset/others/bird.0b77ee66_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._bird.0b77ee66_nohash_0.wav
#   inflating: dataset/others/four.0ab3b47d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._four.0ab3b47d_nohash_1.wav
#   inflating: dataset/others/sheila.0bfec55f_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._sheila.0bfec55f_nohash_0.wav
#   inflating: dataset/others/zero.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._zero.0a2b400e_nohash_3.wav
#   inflating: dataset/others/up.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._up.0a196374_nohash_1.wav
#   inflating: dataset/others/stop.0b7ee1a0_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._stop.0b7ee1a0_nohash_1.wav
#   inflating: dataset/others/stop.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._stop.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/tree.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0a5636ca_nohash_0.wav
#   inflating: dataset/others/up.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._up.0a196374_nohash_0.wav
#   inflating: dataset/others/zero.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._zero.0a2b400e_nohash_2.wav
#   inflating: dataset/others/stop.0a5636ca_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._stop.0a5636ca_nohash_0.wav
#   inflating: dataset/others/up.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._up.0a2b400e_nohash_4.wav
#   inflating: dataset/others/cat.0d6d7360_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._cat.0d6d7360_nohash_0.wav
#   inflating: dataset/others/four.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._four.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/wow.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._wow.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/stop.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._stop.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/three.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._three.0a196374_nohash_1.wav
#   inflating: dataset/others/left.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._left.0a2b400e_nohash_2.wav
#   inflating: dataset/others/wow.0ac15fe9_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._wow.0ac15fe9_nohash_1.wav
#   inflating: dataset/others/five.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._five.0a196374_nohash_0.wav
#   inflating: dataset/others/five.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._five.0a2b400e_nohash_4.wav
#   inflating: dataset/others/left.0a7c2a8d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._left.0a7c2a8d_nohash_1.wav
#   inflating: dataset/others/learn.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._learn.0a2b400e_nohash_3.wav
#   inflating: dataset/others/house.0ac15fe9_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._house.0ac15fe9_nohash_3.wav
#   inflating: dataset/others/marvin.0b09edd3_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._marvin.0b09edd3_nohash_0.wav
#   inflating: dataset/others/tree.0b56bcfe_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._tree.0b56bcfe_nohash_0.wav
#   inflating: dataset/others/three.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._three.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/visual.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._visual.0a2b400e_nohash_3.wav
#   inflating: dataset/others/four.0b7ee1a0_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._four.0b7ee1a0_nohash_0.wav
#   inflating: dataset/others/five.0a9f9af7_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._five.0a9f9af7_nohash_1.wav
#   inflating: dataset/others/no.0a396ff2_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._no.0a396ff2_nohash_0.wav
#   inflating: dataset/others/eight.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._eight.0a196374_nohash_2.wav
#   inflating: dataset/others/two.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._two.0a196374_nohash_0.wav
#   inflating: dataset/others/one.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._one.0a196374_nohash_2.wav
#   inflating: dataset/others/one.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._one.0a196374_nohash_3.wav
#   inflating: dataset/others/two.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._two.0a196374_nohash_1.wav
#   inflating: dataset/others/eight.0a196374_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._eight.0a196374_nohash_3.wav
#   inflating: dataset/others/visual.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._visual.0a2b400e_nohash_2.wav
#   inflating: dataset/others/five.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._five.0a9f9af7_nohash_0.wav
#   inflating: dataset/others/marvin.0b40aa8e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._marvin.0b40aa8e_nohash_0.wav
#   inflating: dataset/others/marvin.0b09edd3_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._marvin.0b09edd3_nohash_1.wav
#   inflating: dataset/others/house.0ac15fe9_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._house.0ac15fe9_nohash_2.wav
#   inflating: dataset/others/learn.0a2b400e_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._learn.0a2b400e_nohash_2.wav
#   inflating: dataset/others/left.0a7c2a8d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._left.0a7c2a8d_nohash_0.wav
#   inflating: dataset/others/on.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._on.0a196374_nohash_2.wav
#   inflating: dataset/others/five.0a196374_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._five.0a196374_nohash_1.wav
#   inflating: dataset/others/wow.0ac15fe9_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._wow.0ac15fe9_nohash_0.wav
#   inflating: dataset/others/house.0a2b400e_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._house.0a2b400e_nohash_0.wav
#   inflating: dataset/others/left.0a2b400e_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._left.0a2b400e_nohash_3.wav
#   inflating: dataset/others/three.0a196374_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._three.0a196374_nohash_0.wav
#   inflating: dataset/others/three.0a2b400e_nohash_4.wav
#   inflating: __MACOSX/dataset/others/._three.0a2b400e_nohash_4.wav
#   inflating: dataset/others/wow.0a7c2a8d_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._wow.0a7c2a8d_nohash_1.wav
#   inflating: dataset/others/on.0a9f9af7_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._on.0a9f9af7_nohash_1.wav
#   inflating: dataset/others/wow.0a7c2a8d_nohash_3.wav
#   inflating: __MACOSX/dataset/others/._wow.0a7c2a8d_nohash_3.wav
#   inflating: dataset/others/three.0a196374_nohash_2.wav
#   inflating: __MACOSX/dataset/others/._three.0a196374_nohash_2.wav
#   inflating: dataset/others/go.0ab3b47d_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._go.0ab3b47d_nohash_0.wav
#   inflating: dataset/others/left.0a2b400e_nohash_1.wav
#   inflating: __MACOSX/dataset/others/._left.0a2b400e_nohash_1.wav
#   inflating: dataset/others/eight.0a9f9af7_nohash_0.wav
#   inflating: __MACOSX/dataset/others/._eight.0a9f9af7_nohash_0.wav
# ...
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s30.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s30.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s24.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s24.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s18.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s18.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s4.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s4.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s43.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s43.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s57.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s57.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s80.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s80.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s94.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s94.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s95.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s95.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s81.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s81.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s56.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s56.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s42.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s42.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s5.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s5.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s19.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s19.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s25.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s25.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s31.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s31.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s153.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s153.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s147.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s147.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s151.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s151.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s145.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s145.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s27.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s27.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s33.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s33.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s7.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s7.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s54.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s54.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s40.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s40.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s68.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s68.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s97.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s97.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s83.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s83.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s82.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s82.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s96.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s96.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s69.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s69.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s41.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s41.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s55.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s55.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s6.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s6.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s32.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s32.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s26.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s26.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s144.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s144.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s150.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s150.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s137.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s137.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s123.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s123.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s41.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s41.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s55.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s55.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s32.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s32.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s26.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s26.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s27.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s27.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s33.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s33.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s54.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s54.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s40.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s40.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s122.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s122.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s136.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s136.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s120.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s120.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s134.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s134.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s108.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s108.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s56.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s56.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s42.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s42.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s19.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s19.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s25.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s25.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s31.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s31.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s30.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s30.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s24.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s24.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s18.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s18.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s43.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s43.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s57.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s57.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s109.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s109.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s135.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s135.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s121.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s121.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s119.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s119.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s125.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s125.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s131.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s131.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s53.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s53.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s47.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s47.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s20.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s20.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s34.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s34.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s35.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s35.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s21.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s21.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s46.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s46.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s52.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s52.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s130.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s130.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s124.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s124.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s118.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s118.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s132.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s132.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s126.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s126.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s44.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s44.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s50.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s50.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s37.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s37.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s23.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s23.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s22.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s22.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s36.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s36.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s51.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s51.wav
#   inflating: dataset/user_0/user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s45.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nda9no0.ingestion-856ccfd98c-f8vjf.s45.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s127.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s127.wav
#   inflating: dataset/user_0/user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s133.wav
#   inflating: __MACOSX/dataset/user_0/._user_0.5nd9nbmm.ingestion-856ccfd98c-b25gl.s133.wav

# %% [markdown]
# Dividing the files in the desired folders, that will then be processed in .npy files

# %% [markdown]
# Division and organization:

# %%
import os
import shutil
import random
from tqdm import tqdm

def organize_wav_files(target_source_dir, other_source_dir, output_dir, target_user_id=0):
    """
    Organizes wav files into structured folders for speaker verification.

    Args:
        target_source_dir: Directory containing target speaker's wav files (user_0/)
        other_source_dir: Directory containing other speakers' wav files (other_users/)
        output_dir: Output directory for organized files
        target_user_id: Numeric ID for target speaker
    """
    os.makedirs(output_dir, exist_ok=True)

    # Directory structure
    subfolders = {
        "validation": (60, 120),    # (target_samples, non_target_samples)
        "testing": (60, 120),
        "train_1": (1, 0),
        "train_8": (8, 0),
        "train_16": (16, 0),
        "train_64": (64, 0)
    }

    # Create all folders
    for folder in subfolders:
        os.makedirs(os.path.join(output_dir, folder), exist_ok=True)

    # Load target speaker files
    target_files = [f for f in os.listdir(target_source_dir)
                   if f.endswith('.wav') and os.path.isfile(os.path.join(target_source_dir, f))]
    random.shuffle(target_files)

    # Load non-target speaker files
    other_files = []
    for root, _, files in os.walk(other_source_dir):
        for file in files:
            if file.endswith('.wav'):
                other_files.append(os.path.join(root, file))
    random.shuffle(other_files)

    # Verify we have enough files
    required_target = sum(v[0] for v in subfolders.values())
    required_other = sum(v[1] for v in subfolders.values())

    if len(target_files) < required_target:
        raise ValueError(f"Need {required_target} target files, found {len(target_files)}")
    if len(other_files) < required_other:
        raise ValueError(f"Need {required_other} non-target files, found {len(other_files)}")

    # Organize files
    target_idx = 0
    other_idx = 0

    for folder, (target_count, other_count) in subfolders.items():
        # Move target speaker files
        for i in range(target_count):
            if target_idx >= len(target_files):
                break
            src = os.path.join(target_source_dir, target_files[target_idx])
            dst = os.path.join(output_dir, folder, f"target_{target_files[target_idx]}")
            shutil.copy(src, dst)
            target_idx += 1

        # Move non-target speaker files
        for i in range(other_count):
            if other_idx >= len(other_files):
                break
            src = other_files[other_idx]
            dst = os.path.join(output_dir, folder, f"other_{os.path.basename(src)}")
            shutil.copy(src, dst)
            other_idx += 1

    print("Organization complete.")
    print(f"Used {target_idx} target files and {other_idx} non-target files")
    print(f"Remaining target files: {len(target_files) - target_idx}")
    print(f"Remaining non-target files: {len(other_files) - other_idx}")

if __name__ == "__main__":
    # Configure these paths
    target_speaker_dir = "/content/dataset/user_0/"  # Contains only target speaker
    other_speakers_dir = "/content/dataset/others/"  # Contains other speakers
    output_directory = "/content/dataset/user_0_organized/"

    organize_wav_files(
        target_source_dir=target_speaker_dir,
        other_source_dir=other_speakers_dir,
        output_dir=output_directory,
        target_user_id=0
    )
    # !rm -r /content/dataset/user_0
    # !rm -r /content/dataset/others
# Out:
# Organization complete.
# Used 209 target files and 240 non-target files
# Remaining target files: 27
# Remaining non-target files: 248

# %% [markdown]
# MFE block conversion and .npz file generation

# %%
import os
import shutil
import numpy as np
import librosa
from tqdm import tqdm

SAMPLE_RATE = 16000
FRAME_SIZE = 512
HOP_LENGTH = 384
N_FFT = 512
N_MELS = 40
PRE_EMPHASIS_COEFF = 0.96785

def remove_all_folders_except(parent_dir, folder_to_keep):
    keep_path = os.path.join(parent_dir, folder_to_keep)
    if not os.path.exists(keep_path):
        print(f"Warning: '{folder_to_keep}' doesn't exist in {parent_dir}")
        return

    for item in os.listdir(parent_dir):
        item_path = os.path.join(parent_dir, item)
        if os.path.isdir(item_path) and item != folder_to_keep:
            print(f"Removing: {item_path}")
            try:
                shutil.rmtree(item_path)
            except Exception as e:
                print(f"Failed to remove {item_path}: {e}")

def apply_pre_emphasis(y, coeff=PRE_EMPHASIS_COEFF):
    emphasized = np.zeros_like(y, dtype=np.float32)
    emphasized[0] = y[0]
    for i in range(1, len(y)):
        emphasized[i] = y[i] - coeff * y[i-1]
    return emphasized

def extract_mfe(waveform):
    emphasized = apply_pre_emphasis(waveform)

    stft = librosa.stft(
        emphasized,
        n_fft=N_FFT,
        hop_length=HOP_LENGTH,
        win_length=FRAME_SIZE,
        window='hamming'
    )
    spectrogram = np.abs(stft)
    spectrogram = 10 * np.log10(spectrogram**2 + 1e-20)
    spectrogram = np.maximum(spectrogram, -50)
    spectrogram = (spectrogram + 50) / 62
    mel_basis = librosa.filters.mel(
        sr=SAMPLE_RATE,
        n_fft=N_FFT,
        n_mels=N_MELS,
        fmin=0,
        fmax=8000
    )
    mfe = np.dot(mel_basis, spectrogram)
    mfe = mfe.T
    mfe = mfe[:40, :]

    return mfe

def process_folder_to_npz(folder_path, output_npz_path, target_user_id):
    features = []
    labels = []
    filenames = []

    wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    for wav_file in tqdm(wav_files, desc=f"Processing {os.path.basename(folder_path)}"):
        audio_path = os.path.join(folder_path, wav_file)
        try:
            y, sr = librosa.load(audio_path, sr=SAMPLE_RATE)
        except:
            print(f"Skipping corrupted file: {audio_path}")
            continue

        if len(y) != SAMPLE_RATE:
            print(f"Warning: {wav_file} has {len(y)/SAMPLE_RATE:.2f} seconds (expected 1.0)")
            continue

        mfe = extract_mfe(y)
        mfe = mfe[..., np.newaxis]
        features.append(mfe)

        if wav_file.startswith('target_'):
            labels.append(target_user_id)
        else:
            labels.append(-1)

        filenames.append(wav_file)

    features_array = np.array(features, dtype=np.float32)
    labels_array = np.array(labels, dtype=np.int32)

    np.savez_compressed(
        output_npz_path,
        features=features_array,
        filenames=np.array(filenames),
        labels=labels_array
    )
    print(f"Saved {len(features)} segments to {output_npz_path}")
    print(f"Class distribution: Target={np.sum(labels_array == target_user_id)}, Non-target={np.sum(labels_array != target_user_id)}")

def process_all_folders(base_dir, target_user_id=0):
    """Process all subfolders in the organized directory"""
    subfolders = [
        "validation",
        "testing",
        "train_1",
        "train_8",
        "train_16",
        "train_64"
    ]

    output_dir = os.path.join(base_dir, "npz_features")
    os.makedirs(output_dir, exist_ok=True)

    for folder in subfolders:
        folder_path = os.path.join(base_dir, folder)
        if os.path.exists(folder_path):
            if "train" in folder:
                output_filename = f"{folder}_{target_user_id}_features.npz"
            else:
                output_filename = f"{folder}_features.npz"

            output_path = os.path.join(output_dir, output_filename)
            process_folder_to_npz(folder_path, output_path, target_user_id)

if __name__ == "__main__":
    organized_dir = "/content/dataset/user_0_organized"
    target_speaker_id = 0

    print("Verifying folder structure...")
    for folder in ["validation", "testing", "train_1", "train_8", "train_16", "train_64"]:
        path = os.path.join(organized_dir, folder)
        if os.path.exists(path):
            files = [f for f in os.listdir(path) if f.endswith('.wav')]
            print(f"{folder}: {len(files)} files")

    process_all_folders(organized_dir, target_user_id=target_speaker_id)
    remove_all_folders_except(parent_dir=organized_dir, folder_to_keep="npz_features")
# Out:
# Verifying folder structure...
# validation: 180 files
# testing: 180 files
# train_1: 1 files
# train_8: 8 files
# train_16: 16 files
# train_64: 64 files
# Processing validation:   6%|▌         | 10/180 [00:00<00:01, 95.78it/s]
# Warning: other_wow.0ab3b47d_nohash_0.wav has 0.90 seconds (expected 1.0)
# Warning: other_yes.0a5636ca_nohash_0.wav has 0.60 seconds (expected 1.0)
# Processing validation:  12%|█▏        | 21/180 [00:00<00:01, 100.87it/s]
# Warning: other_bird.0a9f9af7_nohash_0.wav has 0.94 seconds (expected 1.0)
# Processing validation:  18%|█▊        | 33/180 [00:00<00:01, 107.21it/s]
# Warning: other_sheila.0a5636ca_nohash_1.wav has 0.84 seconds (expected 1.0)
# Warning: other_six.0a396ff2_nohash_0.wav has 0.55 seconds (expected 1.0)
# Processing validation:  37%|███▋      | 66/180 [00:00<00:01, 104.78it/s]
# Warning: target_user_0.5nd9qqrk.ingestion-856ccfd98c-7psd8.wav has 100.00 seconds (expected 1.0)
# Warning: other_left.0a5636ca_nohash_1.wav has 0.88 seconds (expected 1.0)
# Warning: other_bird.0a396ff2_nohash_0.wav has 0.47 seconds (expected 1.0)
# Warning: other_no.0a5636ca_nohash_1.wav has 0.60 seconds (expected 1.0)
# Processing validation:  63%|██████▎   | 114/180 [00:01<00:00, 108.68it/s]
# Warning: other_marvin.0a9f9af7_nohash_0.wav has 0.85 seconds (expected 1.0)
# Warning: other_left.0a5636ca_nohash_0.wav has 0.84 seconds (expected 1.0)
# Warning: other_nine.0a5636ca_nohash_0.wav has 0.93 seconds (expected 1.0)
# Warning: other_go.0a9f9af7_nohash_1.wav has 0.85 seconds (expected 1.0)
# Processing validation:  82%|████████▏ | 147/180 [00:01<00:00, 105.16it/s]
# Warning: other_down.0a9f9af7_nohash_0.wav has 0.85 seconds (expected 1.0)
# Warning: other_cat.0c09f202_nohash_0.wav has 0.81 seconds (expected 1.0)
# Processing validation: 100%|██████████| 180/180 [00:01<00:00, 105.95it/s]
# Warning: target_user_0.5nd9rh04.ingestion-856ccfd98c-f8vjf.wav has 15.00 seconds (expected 1.0)
# Warning: other_cat.0c540988_nohash_0.wav has 0.77 seconds (expected 1.0)
# Warning: other_happy.0a5636ca_nohash_0.wav has 0.88 seconds (expected 1.0)
# Saved 162 segments to /content/dataset/user_0_organized/npz_features/validation_features.npz
# Class distribution: Target=58, Non-target=104
# Processing testing:  18%|█▊        | 33/180 [00:00<00:01, 108.48it/s]
# Warning: other_house.0a396ff2_nohash_0.wav has 0.64 seconds (expected 1.0)
# Warning: other_on.0a7c2a8d_nohash_0.wav has 0.98 seconds (expected 1.0)
# Warning: other_six.0a9f9af7_nohash_0.wav has 0.73 seconds (expected 1.0)
# Processing testing:  31%|███       | 56/180 [00:00<00:01, 111.56it/s]
# Warning: other_five.0a396ff2_nohash_0.wav has 0.55 seconds (expected 1.0)
# Warning: other_marvin.0b09edd3_nohash_1.wav has 0.94 seconds (expected 1.0)
# Warning: other_tree.0b09edd3_nohash_0.wav has 0.64 seconds (expected 1.0)
# Warning: other_on.0a5636ca_nohash_0.wav has 0.93 seconds (expected 1.0)
# Warning: other_no.0a5636ca_nohash_0.wav has 0.74 seconds (expected 1.0)
# Warning: other_no.0a9f9af7_nohash_0.wav has 0.68 seconds (expected 1.0)
# Warning: other_four.0a9f9af7_nohash_0.wav has 0.94 seconds (expected 1.0)
# Warning: other_dog.0ab3b47d_nohash_0.wav has 0.90 seconds (expected 1.0)
# Processing testing:  54%|█████▍    | 97/180 [00:00<00:00, 114.95it/s]
# Warning: other_marvin.0b57a6ed_nohash_0.wav has 0.98 seconds (expected 1.0)
# Warning: other_right.0a5636ca_nohash_0.wav has 0.70 seconds (expected 1.0)
# Processing testing:  67%|██████▋   | 121/180 [00:01<00:00, 108.22it/s]
# Warning: other_bird.0a5636ca_nohash_0.wav has 0.84 seconds (expected 1.0)
# Warning: other_five.0a9f9af7_nohash_1.wav has 0.85 seconds (expected 1.0)
# Processing testing:  81%|████████  | 146/180 [00:01<00:00, 113.90it/s]
# Warning: other_go.0ab3b47d_nohash_0.wav has 0.81 seconds (expected 1.0)
# Warning: other_left.0a9f9af7_nohash_0.wav has 0.77 seconds (expected 1.0)
# Warning: other_cat.0bfec55f_nohash_0.wav has 0.77 seconds (expected 1.0)
# Warning: other_visual.0b139000_nohash_0.wav has 0.85 seconds (expected 1.0)
# Warning: other_house.0a9f9af7_nohash_0.wav has 0.73 seconds (expected 1.0)
# Processing testing:  94%|█████████▍| 170/180 [00:01<00:00, 112.38it/s]
# Warning: other_learn.0b139000_nohash_0.wav has 0.73 seconds (expected 1.0)
# Warning: other_wow.0a5636ca_nohash_0.wav has 0.79 seconds (expected 1.0)
# Processing testing: 100%|██████████| 180/180 [00:01<00:00, 112.08it/s]
# Warning: other_bird.0b57a6ed_nohash_0.wav has 0.77 seconds (expected 1.0)
# Saved 157 segments to /content/dataset/user_0_organized/npz_features/testing_features.npz
# Class distribution: Target=60, Non-target=97
# Processing train_1: 100%|██████████| 1/1 [00:00<00:00, 78.44it/s]
# Saved 1 segments to /content/dataset/user_0_organized/npz_features/train_1_0_features.npz
# Class distribution: Target=1, Non-target=0
# Processing train_8: 100%|██████████| 8/8 [00:00<00:00, 63.56it/s]
# Saved 8 segments to /content/dataset/user_0_organized/npz_features/train_8_0_features.npz
# Class distribution: Target=8, Non-target=0
# Processing train_16: 100%|██████████| 16/16 [00:00<00:00, 56.30it/s]
# Saved 16 segments to /content/dataset/user_0_organized/npz_features/train_16_0_features.npz
# Class distribution: Target=16, Non-target=0
# Processing train_64: 100%|██████████| 64/64 [00:01<00:00, 55.67it/s]
# Saved 64 segments to /content/dataset/user_0_organized/npz_features/train_64_0_features.npz
# Class distribution: Target=64, Non-target=0
# Removing: /content/dataset/user_0_organized/testing
# Removing: /content/dataset/user_0_organized/train_8
# Removing: /content/dataset/user_0_organized/validation
# Removing: /content/dataset/user_0_organized/train_1
# Removing: /content/dataset/user_0_organized/train_64
# Removing: /content/dataset/user_0_organized/train_16

# %% [markdown]
# Code for verifying the structure of .npz files

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

def verify_npz_files(directory="/content/dataset/user_0_organized/npz_features"):
    """Verify contents of .npz files in a directory."""
    npz_files = [f for f in os.listdir(directory) if f.endswith('.npz')]

    if not npz_files:
        print(f"No .npz files found in {directory}!")
        return

    print(f"Found {len(npz_files)} .npz files in {directory}:\n")

    for file in sorted(npz_files):
        filepath = os.path.join(directory, file)
        data = np.load(filepath)

        print(f"File: {file}")
        print(f"Number of arrays stored: {len(data.files)}\n")

        for array_name in data.files:
            array_data = data[array_name]

            print(f"  Array: '{array_name}'")
            if(array_name=='features'):
              print(f"    - Shape: {array_data.shape}")
              print(f"    - Dtype: {array_data.dtype}")
              print(f"    - Min: {np.min(array_data):.4f}, Max: {np.max(array_data):.4f}, Mean: {np.mean(array_data):.4f}")
              print(f"    - Size: {array_data.size} elements\n")

        print("-" * 50 + "\n")

if __name__ == "__main__":
    verify_npz_files()
# Out:
# Found 6 .npz files in /content/dataset/user_0_organized/npz_features:
#
# File: testing_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (157, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.0388, Mean: 0.0076
#     - Size: 251200 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: train_16_0_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (16, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.0358, Mean: 0.0085
#     - Size: 25600 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: train_1_0_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (1, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.0308, Mean: 0.0095
#     - Size: 1600 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: train_64_0_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (64, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.0366, Mean: 0.0087
#     - Size: 102400 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: train_8_0_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (8, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.0332, Mean: 0.0073
#     - Size: 12800 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------
#
# File: validation_features.npz
# Number of arrays stored: 3
#
#   Array: 'features'
#     - Shape: (162, 40, 40, 1)
#     - Dtype: float32
#     - Min: 0.0000, Max: 0.0368, Mean: 0.0078
#     - Size: 259200 elements
#
#   Array: 'filenames'
#   Array: 'labels'
# --------------------------------------------------

# %% [markdown]
# Bestmatching

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import math

import sys

import random
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

import shutil
tfk = tf.keras
tfkl = tf.keras.layers

print(tf.__version__)

seed = 22

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

dv_model=None

def cosine_similarity(vec1, vec2):
  dot_product = np.dot(vec1, vec2)
  norm_vec1 = np.linalg.norm(vec1)
  norm_vec2 = np.linalg.norm(vec2)
  return dot_product / (norm_vec1 * norm_vec2)

def compute_similarity(input_vector, d_vectors):
  similarities = []

  for dv in d_vectors:
    similarity = cosine_similarity(input_vector, dv)
    similarities.append(similarity)

  return max(similarities)

def predictDVector(d_vectors,authlabel,input_data, input_labels, threshold, verbose=True):
  input_vectors = dv_model.predict(input_data)
  total = len(input_vectors)
  total_auth = 0
  total_denied = 0

  for i in range(len(input_labels)):
    if(input_labels[i]!=auth_class):
      total_denied = total_denied+1
    else:
      total_auth = total_auth + 1

  correct_auth=0
  correct_denied=0

  for i in range(len(input_vectors)):
    similarity=compute_similarity(input_vectors[i], d_vectors)
    result = " -- ERROR!"
    if(similarity>threshold and input_labels[i] == authlabel):
      correct_auth = correct_auth + 1
      result = ""
    if(similarity<=threshold and input_labels[i] != authlabel):
      correct_denied = correct_denied + 1
      result = ""
    if(verbose):
      print("similarity: " + str(similarity) + " --- Class: " + str(input_labels[i]) + " " + result)
  correct = correct_auth + correct_denied

  print('-----------------------')
  print(" --- Testing Results ---")
  true_positive = correct_auth
  false_positive = total_denied - correct_denied
  false_negative = total_auth - correct_auth
  prec = true_positive / (true_positive + false_positive)
  recall = true_positive / (true_positive + false_negative)

  print("True Positive Rate: " + str(correct_auth) + "/" + str(total_auth) + " (" + str(correct_auth*100/total_auth) + "%)")
  print("False Positive Rate: " + str(false_positive) + "/" + str(total_denied) + " (" + str((false_positive)*100/total_denied) + "%)")
  print("Precision: " + str(prec))
  print("Recall: " + str(recall))
  print('******************')
  print("Total correct " + str(correct) + "/" + str(total))
  acc = correct/total
  f1score = 2*prec*recall/(prec+recall)
  print("Accuracy on this dataset: " + str(acc))
  print("F1-Score on this dataset: " + str(f1score))

  return acc, f1score

def provide_predictions(d_vectors, input_data):
  y_predictions_prob = np.zeros((len(input_data), 1))
  input_vectors = dv_model.predict(input_data)
  for i in range(len(input_vectors)):
    similarity=compute_similarity(input_vectors[i], d_vectors)
    y_predictions_prob[i] = similarity
  return y_predictions_prob

def evaluate_model(auth_class, train_size):
  print("Testing with speaker id: " + str(auth_class) + " and train size: " + str(train_size))

  train_dir = f"dataset/user_0_organized/npz_features/train_{train_size}_{auth_class}_features.npz"
  training_npz = np.load(train_dir)
  x_train = training_npz['features']

  val_dir = "dataset/user_0_organized/npz_features/validation_features.npz"
  validation_npz = np.load(val_dir)
  x_val, y_val = validation_npz['features'], validation_npz['labels']

  print("Validation class distribution:", np.unique(y_val, return_counts=True))

  testing_dir = "dataset/user_0_organized/npz_features/testing_features.npz"
  testing_npz = np.load(testing_dir)
  x_test, y_test = testing_npz['features'], testing_npz['labels']

  print("=== Dataset Summary ===")
  print(f"Training: {len(x_train)} samples (should include both classes)")
  print(f"Validation: {len(x_val)} samples - Classes: {np.unique(y_val, return_counts=True)}")
  print(f"Testing: {len(x_test)} samples - Classes: {np.unique(y_test, return_counts=True)}")

  d_vectors = dv_model.predict(x_train.reshape(train_size,40,40,1))
  print(d_vectors.shape)

  save_path = f"d_vectors_{auth_class}_{train_size}.npz"
  np.savez(save_path, labels=y_val, d_vectors=d_vectors)
  print(f"Saved d_vectors and labels to {save_path}")

  y_pred_prob = provide_predictions(d_vectors, x_val)

  y_val_bin = np.where(y_val == auth_class, 1, 0)

  for i,classvalue in enumerate(y_val):
    if(classvalue!=auth_class):
      y_val_bin[i] = 0

  if len(np.unique(y_val_bin)) > 1:
    fpr, tpr, thresholds = roc_curve(y_val_bin, y_pred_prob)
    roc_auc = auc(fpr, tpr)
    print("-----")

    print("Plotting the Receiving Operating Characteristic curve:")
    '''
    # Plot ROC curve
    plt.plot(fpr, tpr, 'b', label='AUC = %0.2f'% roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'r--')
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    '''
    fnr = 1 - tpr
    try:
      eer_threshold = thresholds[np.nanargmin(np.absolute((fnr - fpr)))]
      print("-----")
      print("EER Threshold: ", eer_threshold)
      abs_diffs = np.abs(fpr - fnr)
      min_index = np.argmin(abs_diffs)
      EER = np.mean((fpr[min_index], fnr[min_index]))
    except:
      eer_threshold=0.5
      EER=1.0
      print(print("Warning: EER calculation failed - using default threshold"))

  else:
    print("Warning: Only one class present in validation data")
    eer_threshold = 0.5
    EER = 1.0
    roc_auc = 0.5
    print("EER = " + str(EER))
    print("AUC = " + str(roc_auc))

  acc, f1score = predictDVector(d_vectors, auth_class, x_test, y_test, threshold=eer_threshold, verbose=False)

  with open("test-results-td-bestmatch.txt", "a") as f:
      f.write(f"Speaker {auth_class} | Train Size: {train_size}\n")
      f.write(f"Accuracy: {acc:.4f} | F1: {f1score:.4f} | EER: {EER:.4f} | AUC: {roc_auc:.4f}\n")
      f.close

def main():
    auth_class = 0
    train_sizes = [1, 8, 16, 64]

    global dv_model

    d_vector_model_name = "d-vector-extractor-256.h5"
    dv_model = tfk.models.load_model(d_vector_model_name)
    dv_model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                    optimizer=tfk.optimizers.Adam(learning_rate=0.0001),
                    metrics=['accuracy'])
    dv_model.summary()
    with open("test-results-td-bestmatch.txt", "w") as f:
        f.write("Speaker Verification Results\n")
        f.write("==========================\n\n")

    for size in train_sizes:
        evaluate_model(auth_class, size)

if __name__ == "__main__":
    # !rm -r /content/d_vectors/
    main()
    # !mkdir /content/d_vectors/
    # !mv d_vectors* /content/d_vectors/
# Out:
# 2.18.0
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "d-vector-extractor-256"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization                  │ (None, 40, 40, 1)           │               4 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 40, 40, 8)           │              80 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 13, 13, 16)          │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 3, 3, 32)            │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 2, 2, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,388 (95.27 KB)
#  Trainable params: 24,386 (95.26 KB)
#  Non-trainable params: 2 (8.00 B)
# Testing with speaker id: 0 and train size: 1
# Validation class distribution: (array([-1,  0], dtype=int32), array([104,  58]))
# === Dataset Summary ===
# Training: 1 samples (should include both classes)
# Validation: 162 samples - Classes: (array([-1,  0], dtype=int32), array([104,  58]))
# Testing: 157 samples - Classes: (array([-1,  0], dtype=int32), array([97, 60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# (1, 256)
# Saved d_vectors and labels to d_vectors_0_1.npz
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# -----
# Plotting the Receiving Operating Characteristic curve:
# -----
# EER Threshold:  0.5501387715339661
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# -----------------------
#  --- Testing Results ---
# True Positive Rate: 46/60 (76.66666666666667%)
# False Positive Rate: 32/97 (32.98969072164948%)
# Precision: 0.5897435897435898
# Recall: 0.7666666666666667
# ******************
# Total correct 111/157
# Accuracy on this dataset: 0.7070063694267515
# F1-Score on this dataset: 0.6666666666666667
# Testing with speaker id: 0 and train size: 8
# Validation class distribution: (array([-1,  0], dtype=int32), array([104,  58]))
# === Dataset Summary ===
# Training: 8 samples (should include both classes)
# Validation: 162 samples - Classes: (array([-1,  0], dtype=int32), array([104,  58]))
# Testing: 157 samples - Classes: (array([-1,  0], dtype=int32), array([97, 60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# (8, 256)
# Saved d_vectors and labels to d_vectors_0_8.npz
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# -----
# Plotting the Receiving Operating Characteristic curve:
# -----
# EER Threshold:  0.6554604768753052
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# -----------------------
#  --- Testing Results ---
# True Positive Rate: 46/60 (76.66666666666667%)
# False Positive Rate: 19/97 (19.587628865979383%)
# Precision: 0.7076923076923077
# Recall: 0.7666666666666667
# ******************
# Total correct 124/157
# Accuracy on this dataset: 0.7898089171974523
# F1-Score on this dataset: 0.736
# Testing with speaker id: 0 and train size: 16
# Validation class distribution: (array([-1,  0], dtype=int32), array([104,  58]))
# === Dataset Summary ===
# Training: 16 samples (should include both classes)
# Validation: 162 samples - Classes: (array([-1,  0], dtype=int32), array([104,  58]))
# Testing: 157 samples - Classes: (array([-1,  0], dtype=int32), array([97, 60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# (16, 256)
# Saved d_vectors and labels to d_vectors_0_16.npz
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# -----
# Plotting the Receiving Operating Characteristic curve:
# -----
# EER Threshold:  0.6734737753868103
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# -----------------------
#  --- Testing Results ---
# True Positive Rate: 54/60 (90.0%)
# False Positive Rate: 20/97 (20.61855670103093%)
# Precision: 0.7297297297297297
# Recall: 0.9
# ******************
# Total correct 131/157
# Accuracy on this dataset: 0.8343949044585988
# F1-Score on this dataset: 0.8059701492537312
# Testing with speaker id: 0 and train size: 64
# Validation class distribution: (array([-1,  0], dtype=int32), array([104,  58]))
# === Dataset Summary ===
# Training: 64 samples (should include both classes)
# Validation: 162 samples - Classes: (array([-1,  0], dtype=int32), array([104,  58]))
# Testing: 157 samples - Classes: (array([-1,  0], dtype=int32), array([97, 60]))
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# (64, 256)
# Saved d_vectors and labels to d_vectors_0_64.npz
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# -----
# Plotting the Receiving Operating Characteristic curve:
# -----
# EER Threshold:  0.724031388759613
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# -----------------------
#  --- Testing Results ---
# True Positive Rate: 56/60 (93.33333333333333%)
# False Positive Rate: 10/97 (10.309278350515465%)
# Precision: 0.8484848484848485
# Recall: 0.9333333333333333
# ******************
# Total correct 143/157
# Accuracy on this dataset: 0.910828025477707
# F1-Score on this dataset: 0.888888888888889
# mv: cannot move 'd_vectors' to a subdirectory of itself, '/content/d_vectors/d_vectors'

# %% [markdown]
# Mean Cos

# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import roc_curve, auc
import sys

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
seed = 22
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

print(tf.__version__)

def cosine_similarity(vec1, vec2):
    """Compute cosine similarity between two vectors"""
    dot_product = np.dot(vec1, vec2)
    norm_product = np.linalg.norm(vec1) * np.linalg.norm(vec2)
    return dot_product / (norm_product + 1e-8)

def compute_mean_d_vector(d_vectors):
    """Compute the mean d-vector from enrollment samples"""
    return np.mean(d_vectors, axis=0)

def predictDVector(mean_d_vector, authlabel, input_data, input_labels, threshold, verbose=True):
    """Evaluate performance using mean cosine similarity"""
    input_vectors = dv_model.predict(input_data)
    total = len(input_vectors)

    is_target = (input_labels == authlabel)
    total_auth = np.sum(is_target)
    total_denied = total - total_auth

    similarities = np.array([cosine_similarity(vec, mean_d_vector) for vec in input_vectors])
    predictions = similarities > threshold

    true_pos = np.sum(predictions & is_target)
    true_neg = np.sum(~predictions & ~is_target)
    false_pos = np.sum(predictions & ~is_target)
    false_neg = np.sum(~predictions & is_target)

    with np.errstate(divide='ignore', invalid='ignore'):
        prec = true_pos / (true_pos + false_pos) if (true_pos + false_pos) > 0 else 0
        recall = true_pos / total_auth if total_auth > 0 else 0
        f1 = 2 * (prec * recall) / (prec + recall) if (prec + recall) > 0 else 0
        acc = (true_pos + true_neg) / total
        fpr = false_pos / total_denied if total_denied > 0 else 0

    print('-----------------------')
    print(" --- Testing Results ---")
    print(f"Target samples: {total_auth}/{total}")
    print(f"Non-target samples: {total_denied}/{total}")
    print(f"True Positive Rate: {true_pos}/{total_auth} ({true_pos/total_auth*100:.1f}%)")
    print(f"False Positive Rate: {false_pos}/{total_denied} (N/A)" if total_denied == 0 else
          f"False Positive Rate: {false_pos}/{total_denied} ({false_pos/total_denied*100:.1f}%)")
    print(f"Precision: {prec:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")
    print(f"Accuracy: {acc:.4f}")

    return acc, f1

def provide_predictions(mean_d_vector, input_data):
    """Generate similarity predictions using mean d-vector"""
    input_vectors = dv_model.predict(input_data)
    return np.array([cosine_similarity(vec, mean_d_vector) for vec in input_vectors])

def evaluate_model(auth_class, train_size):
    """Complete evaluation pipeline for mean cosine approach"""
    print(f"\nEvaluating speaker {auth_class} with {train_size} enrollment samples (Mean Cosine)")

    try:
        train_dir = f"dataset/user_0_organized/npz_features/train_{train_size}_{auth_class}_features.npz"
        training_npz = np.load(train_dir)
        x_train = training_npz['features']

        val_dir = "dataset/user_0_organized/npz_features/validation_features.npz"
        validation_npz = np.load(val_dir)
        x_val, y_val = validation_npz['features'], validation_npz['labels']

        testing_dir = "dataset/user_0_organized/npz_features/testing_features.npz"
        testing_npz = np.load(testing_dir)
        x_test, y_test = testing_npz['features'], testing_npz['labels']

        print("=== Dataset Summary ===")
        print(f"Training: {len(x_train)} samples")
        print(f"Validation: {len(x_val)} samples - Classes: {np.unique(y_val, return_counts=True)}")
        print(f"Testing: {len(x_test)} samples - Classes: {np.unique(y_test, return_counts=True)}")

        d_vectors = dv_model.predict(x_train.reshape(-1, 40, 40, 1))
        mean_d_vector = compute_mean_d_vector(d_vectors)
        print(f"Mean D-Vector computed using {len(d_vectors)} samples")

        y_pred_prob = provide_predictions(mean_d_vector, x_val.reshape(-1, 40, 40, 1))
        y_val_bin = (y_val == auth_class).astype(int)

        if len(np.unique(y_val_bin)) > 1:
            fpr, tpr, thresholds = roc_curve(y_val_bin, y_pred_prob)
            roc_auc = auc(fpr, tpr)

            fnr = 1 - tpr
            try:
                eer_threshold = thresholds[np.nanargmin(np.absolute((fnr - fpr)))]
                abs_diffs = np.abs(fpr - fnr)
                min_index = np.argmin(abs_diffs)
                EER = np.mean((fpr[min_index], fnr[min_index]))
            except:
                eer_threshold = 0.5
                EER = 1.0
                print("Warning: EER calculation failed - using default threshold")
        else:
            print("Warning: Only one class present in validation data")
            eer_threshold = 0.5
            EER = 1.0
            roc_auc = 0.5

        acc, f1score = predictDVector(mean_d_vector, auth_class,
                                    x_test.reshape(-1, 40, 40, 1), y_test,
                                    threshold=eer_threshold, verbose=False)

        with open("test-results-td-meancos.txt", "a") as f:
            f.write(f"Speaker {auth_class} | Train Size: {train_size}\n")
            f.write(f"Accuracy: {acc:.4f} | F1: {f1score:.4f} ")
            f.write(f"| EER: {EER:.4f} | AUC: {roc_auc:.4f}\n\n")

        return acc, f1score, EER, roc_auc

    except Exception as e:
        print(f"Error in evaluation: {e}")
        return 0, 0, 1, 0

def main():
    auth_class = 0
    train_sizes = [1, 8, 16, 64]

    global dv_model
    d_vector_model_name = "d-vector-extractor-256.h5"
    dv_model = tf.keras.models.load_model(d_vector_model_name)
    dv_model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
                    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                    metrics=['accuracy'])

    with open("test-results-td-meancos.txt", "w") as f:
        f.write("Speaker Verification Results (Mean Cosine)\n")
        f.write("========================================\n\n")

    for size in train_sizes:
        evaluate_model(auth_class, size)

if __name__ == "__main__":
    main()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2.18.0
#
# Evaluating speaker 0 with 1 enrollment samples (Mean Cosine)
# === Dataset Summary ===
# Training: 1 samples
# Validation: 162 samples - Classes: (array([-1,  0], dtype=int32), array([104,  58]))
# Testing: 157 samples - Classes: (array([-1,  0], dtype=int32), array([97, 60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Mean D-Vector computed using 1 samples
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# -----------------------
#  --- Testing Results ---
# Target samples: 60/157
# Non-target samples: 97/157
# True Positive Rate: 46/60 (76.7%)
# False Positive Rate: 32/97 (33.0%)
# Precision: 0.5897
# Recall: 0.7667
# F1-Score: 0.6667
# Accuracy: 0.7070
#
# Evaluating speaker 0 with 8 enrollment samples (Mean Cosine)
# === Dataset Summary ===
# Training: 8 samples
# Validation: 162 samples - Classes: (array([-1,  0], dtype=int32), array([104,  58]))
# Testing: 157 samples - Classes: (array([-1,  0], dtype=int32), array([97, 60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Mean D-Vector computed using 8 samples
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# -----------------------
#  --- Testing Results ---
# Target samples: 60/157
# Non-target samples: 97/157
# True Positive Rate: 46/60 (76.7%)
# False Positive Rate: 22/97 (22.7%)
# Precision: 0.6765
# Recall: 0.7667
# F1-Score: 0.7188
# Accuracy: 0.7707
#
# Evaluating speaker 0 with 16 enrollment samples (Mean Cosine)
# === Dataset Summary ===
# Training: 16 samples
# Validation: 162 samples - Classes: (array([-1,  0], dtype=int32), array([104,  58]))
# Testing: 157 samples - Classes: (array([-1,  0], dtype=int32), array([97, 60]))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Mean D-Vector computed using 16 samples
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# -----------------------
#  --- Testing Results ---
# Target samples: 60/157
# Non-target samples: 97/157
# True Positive Rate: 51/60 (85.0%)
# False Positive Rate: 23/97 (23.7%)
# Precision: 0.6892
# Recall: 0.8500
# F1-Score: 0.7612
# Accuracy: 0.7962
#
# Evaluating speaker 0 with 64 enrollment samples (Mean Cosine)
# === Dataset Summary ===
# Training: 64 samples
# Validation: 162 samples - Classes: (array([-1,  0], dtype=int32), array([104,  58]))
# Testing: 157 samples - Classes: (array([-1,  0], dtype=int32), array([97, 60]))
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Mean D-Vector computed using 64 samples
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# -----------------------
#  --- Testing Results ---
# Target samples: 60/157
# Non-target samples: 97/157
# True Positive Rate: 51/60 (85.0%)
# False Positive Rate: 20/97 (20.6%)
# Precision: 0.7183
# Recall: 0.8500
# F1-Score: 0.7786
# Accuracy: 0.8153

# %% [markdown]
# Inspect .npz structure

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

def verify_npz_files(directory="/content/d_vectors/"):
    """Verify contents of .npz files in a directory."""
    npz_files = [f for f in os.listdir(directory) if f.endswith('.npz')]

    if not npz_files:
        print(f"No .npz files found in {directory}!")
        return

    print(f"Found {len(npz_files)} .npz files in {directory}:\n")

    for file in sorted(npz_files):
        filepath = os.path.join(directory, file)
        data = np.load(filepath)

        print(f"File: {file}")
        print(f"Number of arrays stored: {len(data.files)}\n")

        for array_name in data.files:
            array_data = data[array_name]

            print(f"  Array: '{array_name}'")
            if(array_name=='d_vectors'):
              print(f"    - Shape: {array_data.shape}")
              print(f"    - Dtype: {array_data.dtype}")
              print(f"    - Min: {np.min(array_data):.4f}, Max: {np.max(array_data):.4f}, Mean: {np.mean(array_data):.4f}")
              print(f"    - Size: {array_data.size} elements\n")

        print("-" * 50 + "\n")

if __name__ == "__main__":
    verify_npz_files()
# Out:
# Found 4 .npz files in /content/d_vectors/:
#
# File: d_vectors_0_1.npz
# Number of arrays stored: 2
#
#   Array: 'labels'
#   Array: 'd_vectors'
#     - Shape: (1, 256)
#     - Dtype: float32
#     - Min: 0.0000, Max: 6.1477, Mean: 1.0465
#     - Size: 256 elements
#
# --------------------------------------------------
#
# File: d_vectors_0_16.npz
# Number of arrays stored: 2
#
#   Array: 'labels'
#   Array: 'd_vectors'
#     - Shape: (16, 256)
#     - Dtype: float32
#     - Min: 0.0000, Max: 9.4984, Mean: 1.0236
#     - Size: 4096 elements
#
# --------------------------------------------------
#
# File: d_vectors_0_64.npz
# Number of arrays stored: 2
#
#   Array: 'labels'
#   Array: 'd_vectors'
#     - Shape: (64, 256)
#     - Dtype: float32
#     - Min: 0.0000, Max: 11.3936, Mean: 1.0108
#     - Size: 16384 elements
#
# --------------------------------------------------
#
# File: d_vectors_0_8.npz
# Number of arrays stored: 2
#
#   Array: 'labels'
#   Array: 'd_vectors'
#     - Shape: (8, 256)
#     - Dtype: float32
#     - Min: 0.0000, Max: 6.7960, Mean: 0.9764
#     - Size: 2048 elements
#
# --------------------------------------------------

# %% [markdown]
# Convert .npz file generated in a C header

# %%
import numpy as np
import os

def sanitize_name(name):
    """Sanitize array name for C variable naming."""
    return name.replace('.', '_').replace('-', '_')

def generate_npz_header(npz_dir="/content/d_vectors", output_file="d_vectors.h"):
    """Generate a C header with 2D arrays (samples x 256) from .npz files"""
    npz_files = [f for f in os.listdir(npz_dir) if f.endswith('.npz')]

    with open(output_file, "w") as f:
        f.write("#ifndef D_VECTORS_H\n")
        f.write("#define D_VECTORS_H\n\n")
        f.write("#include <stddef.h>\n\n")

        for file in sorted(npz_files):
            file_path = os.path.join(npz_dir, file)
            with np.load(file_path) as data:
                if 'd_vectors' not in data:
                    continue

                d_vectors = data['d_vectors']
                if d_vectors.ndim != 2 or d_vectors.shape[1] != 256:
                    continue

                array_name = sanitize_name(os.path.splitext(file)[0])
                samples = d_vectors.shape[0]
                f.write(f"// {samples} samples of 256-dimensional vectors\n")
                f.write(f"static const float {array_name}[{samples}][256] = {{\n")
                for sample in d_vectors:
                    f.write("    {")
                    line = ", ".join(f"{x:.6f}f" for x in sample)
                    f.write(line)
                    f.write("},\n")

                f.write("};\n\n")

        f.write("#endif // D_VECTORS_H\n")

if __name__ == "__main__":
    generate_npz_header()
